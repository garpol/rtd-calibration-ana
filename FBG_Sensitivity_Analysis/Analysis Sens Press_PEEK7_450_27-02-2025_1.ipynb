# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

# Archivo ROOT de entrada
input_filename = "/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root"

# Abrir el archivo ROOT con uproot
with uproot.open(input_filename) as file:
    tree = file["resampled_data"]  # nombre correcto del árbol
    data = tree.arrays(library="np")  # Devuelve un diccionario de numpy arrays

# Extraer tiempos y valores de wav[0][0]
times = data["t"]
wav_00 = data["wav"][:, 1, 1]  # Accede correctamente a los datos
press = data["press"]
temp = data["temp"]


# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps, press, marker='o', linestyle='-', label='Data 27-02-25')
plt.xlabel("Time (UTC)")
plt.ylabel("Press (bar)")
plt.title("Pressure Plateaus")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

# Archivo ROOT de entrada
input_filename = "/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root"

# Abrir el archivo ROOT con uproot
with uproot.open(input_filename) as file:
    tree = file["resampled_data"]  # nombre correcto del árbol
    data = tree.arrays(library="np")  # Devuelve un diccionario de numpy arrays

# Extraer tiempos y valores de wav[0][0]
times = data["t"]
wav_ = data["wav"][:, 0, 0]  # Accede correctamente a los datos
press = data["press"]
temp = data["temp"]

umbral_min = 1.5574e-6
umbral_max = 1.5578e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)

# Filtrar los datos y los tiempos
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav]
    
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_00')
plt.xlabel("Time (UTC)")
plt.ylabel("wav")
plt.title("wav00 vs Time")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# Extraer tiempos y valores de wav[0][0]
times = data["t"]
wav_ = data["wav"][:, 1, 0]  # Accede correctamente a los datos
press = data["press"]
temp = data["temp"]

umbral_min = 1.5574e-6
umbral_max = 1.5578e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)

# Filtrar los datos y los tiempos
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav]
    
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_10')
plt.xlabel("Time (UTC)")
plt.ylabel("wav")
plt.title("wav10 vs Time")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

# Archivo ROOT de entrada
input_filename = "/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root"

# Abrir el archivo ROOT con uproot
with uproot.open(input_filename) as file:
    tree = file["resampled_data"]  # nombre correcto del árbol
    data = tree.arrays(library="np")  # Devuelve un diccionario de numpy arrays

# Extraer tiempos y valores de wav[0][0]
times = data["t"]
wav_ = data["wav"][:, 0, 1]  # Accede correctamente a los datos
press = data["press"]
temp = data["temp"]

umbral_min = 1.56e-6
umbral_max = 1.56148e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)

# Filtrar los datos y los tiempos
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav]
    
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_01')
plt.xlabel("Time (UTC)")
plt.ylabel("wav")
plt.title("wav01 vs Time")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# Extraer tiempos y valores de wav[0][0]
times = data["t"]
wav_ = data["wav"][:, 1, 1]  # Accede correctamente a los datos
press = data["press"]
temp = data["temp"]

umbral_min = 1.56e-6
umbral_max = 1.56148e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)

# Filtrar los datos y los tiempos
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav]
    
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_11')
plt.xlabel("Time (UTC)")
plt.ylabel("wav")
plt.title("wav11 vs Time")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

# Archivo ROOT de entrada
input_filename = "/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root"

# Abrir el archivo ROOT con uproot
with uproot.open(input_filename) as file:
    tree = file["resampled_data"]  # nombre correcto del árbol
    data = tree.arrays(library="np")  # Devuelve un diccionario de numpy arrays

# Extraer tiempos y valores de wav[0][0]
times = data["t"]
wav_ = data["wav"][:, 0, 2]  # Accede correctamente a los datos
press = data["press"]
temp = data["temp"]

umbral_min = 1.563e-6
umbral_max = 1.5642e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)

# Filtrar los datos y los tiempos
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav]
    
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_02')
plt.xlabel("Time (UTC)")
plt.ylabel("wav")
plt.title("wav02 vs Time")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# Extraer tiempos y valores de wav[0][0]
times = data["t"]
wav_ = data["wav"][:, 1, 2]  # Accede correctamente a los datos
press = data["press"]
temp = data["temp"]

umbral_min = 1.563e-6
umbral_max = 1.5642e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)

# Filtrar los datos y los tiempos
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav]
    
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_12')
plt.xlabel("Time (UTC)")
plt.ylabel("wav")
plt.title("wav12 vs Time")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

# Archivo ROOT de entrada
input_filename = "/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root"

# Abrir el archivo ROOT con uproot
with uproot.open(input_filename) as file:
    tree = file["resampled_data"]  # Nombre correcto del árbol
    data = tree.arrays(library="np")  # Diccionario de numpy arrays

# Extraer tiempos y valores
times = data["t"]
temp = data["temp"]  # Contiene 8 valores por entrada

# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# 🔹 Graficar TODAS las temperaturas
plt.figure(figsize=(10, 5))
for i in range(4):  # Hay 8 sensores pero solo 4 miden la temperatura dentro 
    plt.plot(timestamps, temp[:, i], marker='o', linestyle='-', label=f'Temp Sensor {i+1}')
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (K)")
plt.title("4 first RTD Sensors Temperature")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# 🔹 Graficar SOLO el sensor 2 (índice 1)
sensor_id = 7  # Seleccionar el segundo sensor (índice 1)

plt.figure(figsize=(10, 5))
plt.plot(timestamps, temp[:, sensor_id], marker='o', linestyle='-', color='r', label=f'Temp Sensor {sensor_id + 1}')
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (K)")
plt.title(f"RTD {sensor_id + 1} Temperature")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

# Archivo ROOT de entrada
input_filename = "/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root"

# Abrir el archivo ROOT con uproot
with uproot.open(input_filename) as file:
    tree = file["resampled_data"]  # Nombre correcto del árbol
    data = tree.arrays(library="np")  # Diccionario de numpy arrays

# Extraer tiempos y valores
times = data["t"]
temp = data["temp"]  # Contiene 8 valores por entrada

# Convertir tiempos a formato datetime
timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])

# 🔹 FILTRAR desde las 13:00 UTC
mask = np.array([t.hour >= 13 for t in timestamps])  # Solo datos con hora >= 13

timestamps_filtrados = timestamps[mask]
temp_filtrado = temp[mask]  # Filtramos también los valores de temperatura

# 🔹 Graficar TODAS las temperaturas filtradas
plt.figure(figsize=(10, 5))
for i in range(4):  # Hay 8 sensores pero solo 4 miden la temperatura dentro 
    plt.plot(timestamps_filtrados, temp_filtrado[:, i], marker='o', linestyle='-', label=f'Temp Sensor {i+1}')
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (K)")
plt.title("4 first RTD Sensors Temperature (≥ 14:00 UTC)")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# 🔹 Graficar SOLO el sensor 1 (índice 0) filtrado
sensor_id = 7  

plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, temp_filtrado[:, sensor_id], marker='o', linestyle='-', color='r', label=f'Temp Sensor {sensor_id + 1}')
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (K)")
plt.title(f"RTD {sensor_id + 1} Temperature (≥ 14:00 UTC)")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

# Archivo ROOT de entrada
input_filename = "/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root"

# Abrir el archivo ROOT con uproot
with uproot.open(input_filename) as file:
    tree = file["resampled_data"]  # Reemplaza con el nombre correcto
    data = tree.arrays(library="np")  # Diccionario de numpy arrays

# Verificar la estructura de "wav"
print(data.keys())  # Verifica las variables en el árbol
if "wav" in data:
    print(f"Shape de 'wav': {data['wav'].shape}")  # Confirmar la estructura

# Extraer tiempos y valores de la polarización 'p' (x=1) del primer sensor (y=0)
times = data["t"]
wav_00_p = data["wav"][:, 0, 0]  # Polarización 'p', Sensor 0

# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# Definir los umbrales
umbral_min = 1.5574e-6
umbral_max = 1.5578e-6

# Aplicar máscara de filtrado
mask = (wav_00_p > umbral_min) & (wav_00_p < umbral_max)

# Filtrar datos
timestamps_filtrados = np.array(timestamps)[mask]
wav_00_p_filtrado = wav_00_p[mask]


# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_00_p_filtrado, marker='o', linestyle='-', label="wav['p'][0] Filtrado")  
plt.xlabel("Tiempo (UTC)")
plt.ylabel("wav[0][0]")
plt.title("Gráfico de wav[0][0] vs Tiempo")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()
# Out:
# dict_keys(['t', 'wav', 'temp', 'press'])
# Shape de 'wav': (2719, 2, 3)

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

def find_plateaus(values, times, tolerance=0.01, min_plateau_length=500):
    """
    Encuentra plateaus en los datos.
    - values: array de valores.
    - times: array de tiempos (segundos desde el epoch).
    - tolerance: diferencia máxima para considerar un plateau.
    - min_plateau_length: duración mínima del plateau en segundos.
    """
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        if abs(values[i] - values[start_idx]) > tolerance:
            duration = times[i - 1] - times[start_idx]
            if duration >= min_plateau_length:
                segment = values[start_idx:i]
                plateaus.append({
                    "t0": times[start_idx],
                    "tfin": times[i - 1],
                    "mean": np.mean(segment),
                    "std": np.std(segment),
                    "data": segment
                })
            start_idx = i  # Reiniciar seguimiento
    
    return plateaus

def calculate_plateaus(input_filename, sensor_temp=0, sensor_wav=(0, 0), params=None):
    """
    Calcula los plateaus para 'press', 'temp' y 'wav' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_temp: índice del sensor de temperatura a considerar.
    sensor_wav: tupla (x, y) del sensor de wav a considerar.
    params: diccionario con parámetros específicos para cada rama {"press": {...}, "temp": {...}, "wav": {...}}
    """
    if params is None:
        params = {
            "press": {"tolerance": 0.01, "min_plateau_length": 500},
            "temp": {"tolerance": 0.01, "min_plateau_length": 500},
            "wav": {"tolerance": 0.01, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])
    
    press_plateaus = find_plateaus(data['press'], times, **params["press"])
    temp_plateaus = find_plateaus([row[sensor_temp] for row in data['temp']], times, **params["temp"])

    # Filtrar los valores de 'wav' según los umbrales
    wav_ = [row[sensor_wav[0]][sensor_wav[1]] for row in data['wav']]
    umbral_min = 1.5574e-6
    umbral_max = 1.5578e-6
    mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
    
    # Filtrar los datos y los tiempos
    timestamps_filtrados = np.array(timestamps)[mask_wav]
    wav_filtrado = np.array(wav_)[mask_wav]
    
    # Ahora calculamos los plateaus para los datos filtrados de 'wav'
    wav_plateaus = find_plateaus(wav_filtrado*1e6, timestamps_filtrados, **params["wav"])
    
    # Graficar los datos con los plateaus por separado
    for branch, series, plateaus, color in zip(["press", "temp", "wav"],
                                                [data['press'], [row[sensor_temp] for row in data['temp']], wav_filtrado*1e6],
                                                [press_plateaus, temp_plateaus, wav_plateaus],
                                                ["blue", "green", "orange"]):
        plt.figure(figsize=(10, 5))
        if branch == "wav":
            # En el caso de 'wav', utilizamos los tiempos y valores filtrados
            plt.plot(timestamps_filtrados, series, marker='o', linestyle='-', label=branch, color=color)
        else:
            # Para 'press' y 'temp', se grafican con los tiempos originales
            plt.plot(timestamps, series, marker='o', linestyle='-', label=branch, color=color)
        
        for plateau in plateaus:
            plt.axvline(x=datetime.datetime.utcfromtimestamp(plateau["t0"]), color='red', linestyle='--', alpha=0.5)
            plt.axvline(x=datetime.datetime.utcfromtimestamp(plateau["tfin"]), color='blue', linestyle='--', alpha=0.5)
        
        plt.xlabel("Time (UTC)")
        plt.ylabel(branch)
        plt.title(f"{branch} vs Time with Plateaus")
        plt.xticks(rotation=45)
        plt.legend()
        plt.grid()
        plt.show()
    
    # Imprimir plateaus de cada rama
    for branch, plateaus in {"press": press_plateaus, "temp": temp_plateaus, "wav": wav_plateaus}.items():
        print(f"\nPlateaus de {branch} detectados:")
        for i, plateau in enumerate(plateaus):
            print(f"Plateau {i}: t0={datetime.datetime.utcfromtimestamp(plateau['t0'])}, "
                  f"tfin={datetime.datetime.utcfromtimestamp(plateau['tfin'])}, "
                  f"mean={plateau['mean']:.6e}, std={plateau['std']:.6e}, "
                  f"data_size={len(plateau['data'])}")
    
    return {"press": press_plateaus, "temp": temp_plateaus, "wav": wav_plateaus}

params = {
    "press": {"tolerance": 0.25, "min_plateau_length": 1000},
    "temp": {"tolerance": 0.5, "min_plateau_length": 800},
    "wav": {"tolerance": 1e-2, "min_plateau_length": 1000}
}

# Ejecutar el cálculo de plateaus
plateaus_result = calculate_plateaus("/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root", sensor_temp=7, sensor_wav=(0, 0), params=params)

#para wav lo hacemos a parte porque la tolerancia es de 1e-5 y da fallos si no cambiamos la estructura de tiempos
# Out:
# Plateaus de press detectados:
# Plateau 0: t0=2025-02-27 11:34:15, tfin=2025-02-27 12:46:15, mean=-1.392096e-02, std=1.592712e-02, data_size=433
# Plateau 1: t0=2025-02-27 12:52:55, tfin=2025-02-27 14:49:35, mean=3.441885e+00, std=5.404076e-02, data_size=701
# Plateau 2: t0=2025-02-27 14:56:35, tfin=2025-02-27 15:46:35, mean=2.857707e+00, std=4.455194e-02, data_size=301
# Plateau 3: t0=2025-02-27 15:48:05, tfin=2025-02-27 16:11:35, mean=2.333700e+00, std=2.334252e-02, data_size=142
# Plateau 4: t0=2025-02-27 16:11:45, tfin=2025-02-27 16:44:35, mean=1.943424e+00, std=9.290598e-02, data_size=198
# Plateau 5: t0=2025-02-27 16:44:45, tfin=2025-02-27 17:06:15, mean=1.755323e+00, std=2.741962e-02, data_size=130
# Plateau 6: t0=2025-02-27 17:15:25, tfin=2025-02-27 17:43:55, mean=7.769167e-01, std=2.313470e-02, data_size=172
#
# Plateaus de temp detectados:
# Plateau 0: t0=2025-02-27 11:34:15, tfin=2025-02-27 12:04:25, mean=2.952202e+02, std=9.031431e-02, data_size=182
# Plateau 1: t0=2025-02-27 12:25:25, tfin=2025-02-27 12:41:25, mean=7.710105e+01, std=7.397207e-02, data_size=97
# Plateau 2: t0=2025-02-27 13:54:05, tfin=2025-02-27 14:47:45, mean=9.212512e+01, std=6.466931e-02, data_size=323
# Plateau 3: t0=2025-02-27 14:52:05, tfin=2025-02-27 15:44:35, mean=9.035651e+01, std=1.219416e-01, data_size=316
# Plateau 4: t0=2025-02-27 15:46:35, tfin=2025-02-27 16:09:25, mean=8.865415e+01, std=4.072744e-02, data_size=138
# Plateau 5: t0=2025-02-27 16:10:55, tfin=2025-02-27 16:32:35, mean=8.710623e+01, std=2.532654e-01, data_size=131
# Plateau 6: t0=2025-02-27 16:43:15, tfin=2025-02-27 17:03:35, mean=8.656563e+01, std=5.178355e-02, data_size=123
# Plateau 7: t0=2025-02-27 17:13:55, tfin=2025-02-27 17:40:45, mean=8.222063e+01, std=4.751336e-02, data_size=162
# Plateau 8: t0=2025-02-27 17:41:35, tfin=2025-02-27 18:32:35, mean=7.710208e+01, std=5.619463e-02, data_size=307
#
# Plateaus de wav detectados:

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

def find_plateaus(values, times, tolerance, min_plateau_length):
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        if abs(values[i] - values[start_idx]) > tolerance:
            duration = times[i - 1] - times[start_idx]

            # Convertir 'duration' de timedelta a segundos
            duration_seconds = duration.total_seconds()

            # Si la duración es suficientemente larga, guardar el plateau
            if duration_seconds >= min_plateau_length:
                segment = values[start_idx:i]

                plateaus.append({
                    "t0": times[start_idx],  # Usar directamente times[start_idx]
                    "tfin": times[i - 1],    # Usar directamente times[i - 1]
                    "duration": duration_seconds,
                    "values": segment
                })

            start_idx = i

    return plateaus

def calculate_wav_plateaus(input_filename, sensor_wav=(0, 0), params=None):
    """
    Calcula los plateaus para 'wav' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_wav: tupla (x, y) del sensor de wav a considerar.
    params: diccionario con parámetros específicos para la rama "wav".
    """
    if params is None:
        params = {
            "wav": {"tolerance": 0.2, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])

    # Filtrar los valores de 'wav' según los umbrales
    wav_ = data["wav"][:, sensor_wav[0], sensor_wav[1]]
    umbral_min = 1.5574e-6
    umbral_max = 1.5578e-6
    mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
    
    # Filtrar los datos y los tiempos
    timestamps_filtrados = np.array(timestamps)[mask_wav]
    wav_filtrado = np.array(wav_)[mask_wav]
    
    # Ahora calculamos los plateaus para los datos filtrados de 'wav'
    wav_plateaus = find_plateaus(wav_filtrado*1e6, timestamps_filtrados, **params["wav"])
    
    # Graficar los datos de 'wav' con los plateaus
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps_filtrados, wav_filtrado*1e6, marker='o', linestyle='-', label="wav", color="orange")
    
    for plateau in wav_plateaus:
        plt.axvline(x=plateau["t0"], color='red', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='blue', linestyle='--', alpha=0.5)
    
    plt.xlabel("Time (UTC)")
    plt.ylabel("wav x 10^6")
    plt.title("wav vs Time with Plateaus")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid()
    plt.show()
    
    # Imprimir los plateaus detectados para 'wav'
    print(f"\nPlateaus de 'wav' detectados:")
    for i, plateau in enumerate(wav_plateaus):
        print(f"Plateau {i}: t0={plateau['t0']}, "
              f"tfin={plateau['tfin']}, "
              f"mean={np.mean(plateau['values']):.6e}, std={np.std(plateau['values']):.6e}, "
              f"data_size={len(plateau['values'])}")
    
    return {"wav": wav_plateaus}


params = {
    "wav": {"tolerance": 0.000015, "min_plateau_length": 1000}
}
print(len(timestamps_filtrados), len(wav_filtrado))  # Verifica que ambas arrays tengan la misma longitud

# Ejecutar el cálculo de plateaus
wav_plateaus_result_00 = calculate_wav_plateaus("/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root", sensor_wav=(0, 0), params=params)

params = {
    "wav": {"tolerance": 0.000008, "min_plateau_length": 1000}
}


wav_plateaus_result_10 = calculate_wav_plateaus("/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root", sensor_wav=(1, 0), params=params)
# Out:
# 2416 2430
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-02-27 12:47:15, tfin=2025-02-27 13:42:55, mean=1.557770e+00, std=2.601286e-06, data_size=335
# Plateau 1: t0=2025-02-27 13:52:35, tfin=2025-02-27 14:38:55, mean=1.557738e+00, std=2.689662e-06, data_size=279
# Plateau 2: t0=2025-02-27 14:39:05, tfin=2025-02-27 15:03:15, mean=1.557707e+00, std=1.405446e-06, data_size=146
# Plateau 3: t0=2025-02-27 15:04:05, tfin=2025-02-27 15:57:25, mean=1.557677e+00, std=7.056734e-06, data_size=321
# Plateau 4: t0=2025-02-27 16:08:15, tfin=2025-02-27 16:34:45, mean=1.557586e+00, std=1.359562e-06, data_size=160
# Plateau 5: t0=2025-02-27 16:35:35, tfin=2025-02-27 17:46:25, mean=1.557491e+00, std=2.811214e-06, data_size=426
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-02-27 12:48:15, tfin=2025-02-27 13:41:55, mean=1.557771e+00, std=1.400996e-06, data_size=323
# Plateau 1: t0=2025-02-27 13:47:05, tfin=2025-02-27 14:38:25, mean=1.557740e+00, std=2.437633e-06, data_size=309
# Plateau 2: t0=2025-02-27 14:39:35, tfin=2025-02-27 15:03:15, mean=1.557707e+00, std=8.352606e-07, data_size=143
# Plateau 3: t0=2025-02-27 15:36:35, tfin=2025-02-27 15:57:25, mean=1.557669e+00, std=9.034829e-07, data_size=126
# Plateau 4: t0=2025-02-27 16:08:15, tfin=2025-02-27 16:34:35, mean=1.557587e+00, std=9.447957e-07, data_size=159
# Plateau 5: t0=2025-02-27 16:35:25, tfin=2025-02-27 17:45:55, mean=1.557492e+00, std=2.582764e-06, data_size=424

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

def find_plateaus(values, times, tolerance=0.01, min_plateau_length=500):
    """
    Encuentra plateaus en los datos.
    - values: array de valores.
    - times: array de tiempos (segundos desde el epoch).
    - tolerance: diferencia máxima para considerar un plateau.
    - min_plateau_length: duración mínima del plateau en segundos.
    """
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        if abs(values[i] - values[start_idx]) > tolerance:
            duration = times[i - 1] - times[start_idx]
            duration_seconds = duration.total_seconds()  # Convertir a segundos
            if duration_seconds >= min_plateau_length:
                segment = values[start_idx:i]
                plateaus.append({
                    "t0": times[start_idx],
                    "tfin": times[i - 1],
                    "mean": np.mean(segment),
                    "std": np.std(segment),
                    "data": segment
                })
            start_idx = i  # Reiniciar seguimiento
    
    return plateaus

def calculate_temp_plateaus(input_filename, sensor_temp=0, params=None):
    """
    Calcula los plateaus para 'temp' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_temp: índice del sensor de temperatura a considerar.
    params: diccionario con parámetros específicos para cada rama {"temp": {...}}
    """
    if params is None:
        params = {
            "temp": {"tolerance": 0.01, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])
    
    # Filtro de tiempo: Seleccionar solo los datos a partir de las 14:00 (hora UTC)
    filter_time = datetime.time(13, 46)  # 14:00 UTC
    timestamps_filtrados = [t for t in timestamps if t.time() >= filter_time]
    temp_filtrado = [row[sensor_temp] for row, t in zip(data['temp'], timestamps) if t in timestamps_filtrados]

    # Calculamos los plateaus de los datos filtrados de temperatura
    temp_plateaus = find_plateaus(temp_filtrado, timestamps_filtrados, **params["temp"])

    # Graficar los datos de temperatura con los plateaus
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps_filtrados, temp_filtrado, marker='o', linestyle='-', label="Data 27-02-2028", color="green")
    
    for plateau in temp_plateaus:
        plt.axvline(x=plateau["t0"], color='red', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='blue', linestyle='--', alpha=0.5)
    
    plt.xlabel("Time (UTC)")
    plt.ylabel("Temperature (K)")
    plt.title(f"Temperature Plateaus (Sensor {sensor_temp})")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid()
    plt.show()
    
    # Imprimir plateaus de temperatura
    print(f"\nPlateaus de temperatura detectados:")
    for i, plateau in enumerate(temp_plateaus):
        print(f"Plateau {i}: t0={plateau['t0']}, "
              f"tfin={plateau['tfin']}, "
              f"mean={plateau['mean']:.6e}, std={plateau['std']:.6e}, "
              f"data_size={len(plateau['data'])}")
    
    return {"temp": temp_plateaus}

params = {
    "temp": {"tolerance": 0.25, "min_plateau_length": 1000}   
}

# Ejecutar el cálculo de plateaus
temp_plateaus_result_7 = calculate_temp_plateaus("/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root", sensor_temp=7, params=params)

params = {
    "temp": {"tolerance": 0.4, "min_plateau_length": 1000}   
}

temp_plateaus_result_6 = calculate_temp_plateaus("/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root", sensor_temp=6, params=params)
# Out:
# Plateaus de temperatura detectados:
# Plateau 0: t0=2025-02-27 13:53:25, tfin=2025-02-27 14:47:15, mean=9.212837e+01, std=4.708926e-02, data_size=324
# Plateau 1: t0=2025-02-27 14:55:05, tfin=2025-02-27 15:44:35, mean=9.035066e+01, std=1.227811e-01, data_size=298
# Plateau 2: t0=2025-02-27 15:46:15, tfin=2025-02-27 16:09:15, mean=8.865817e+01, std=4.034872e-02, data_size=139
# Plateau 3: t0=2025-02-27 16:42:55, tfin=2025-02-27 17:03:25, mean=8.656835e+01, std=4.098481e-02, data_size=124
# Plateau 4: t0=2025-02-27 17:14:05, tfin=2025-02-27 17:40:35, mean=8.222066e+01, std=4.307739e-02, data_size=160
# Plateau 5: t0=2025-02-27 17:42:05, tfin=2025-02-27 18:44:05, mean=7.709108e+01, std=7.141605e-02, data_size=373
# Plateaus de temperatura detectados:
# Plateau 0: t0=2025-02-27 13:55:55, tfin=2025-02-27 14:47:05, mean=9.161853e+01, std=4.320185e-02, data_size=308
# Plateau 1: t0=2025-02-27 15:17:45, tfin=2025-02-27 15:44:35, mean=8.984712e+01, std=1.166188e-01, data_size=162
# Plateau 2: t0=2025-02-27 15:45:45, tfin=2025-02-27 16:09:15, mean=8.815406e+01, std=5.430905e-02, data_size=142
# Plateau 3: t0=2025-02-27 16:42:25, tfin=2025-02-27 17:03:25, mean=8.606193e+01, std=4.837474e-02, data_size=127
# Plateau 4: t0=2025-02-27 17:14:25, tfin=2025-02-27 17:40:35, mean=8.170348e+01, std=4.289785e-02, data_size=158
# Plateau 5: t0=2025-02-27 17:42:05, tfin=2025-02-27 18:44:35, mean=7.655683e+01, std=6.896101e-02, data_size=376

# %%
temp_means_7 = [plateau["mean"] for plateau in temp_plateaus_result_7["temp"]]
temp_means_6 = [plateau["mean"] for plateau in temp_plateaus_result_6["temp"]]
wav_means_00 = [np.mean(plateau['values']) for plateau in wav_plateaus_result_00["wav"]]
wav_means_10 = [np.mean(plateau['values']) for plateau in wav_plateaus_result_10["wav"]]
print(wav_means_00, wav_means_10, temp_means_7, temp_means_6)

# Calcular la desviación estándar de los valores en cada plateau
temp_stds_7 = [plateau["std"]  for plateau in temp_plateaus_result_7["temp"]]
temp_stds_6 = [plateau["std"] for plateau in temp_plateaus_result_6["temp"]]
wav_stds_00 = [np.std(plateau['values']) for plateau in wav_plateaus_result_00["wav"]]
wav_stds_10 = [np.std(plateau['values']) for plateau in wav_plateaus_result_10["wav"]]

# Imprimir resultados
print(wav_stds_00, wav_stds_10, temp_stds_7, temp_stds_6)

print(len(temp_stds_7))
# Out:
# [1.5577704764293163, 1.5577380579435034, 1.5577069011877525, 1.5576766811607707, 1.5575864440644778, 1.557490901837177] [1.5577705352569888, 1.5577398737149604, 1.5577066435353293, 1.5576685379857593, 1.5575865364335235, 1.5574918736561256] [92.12836531893004, 90.35065674328858, 88.65816638968825, 86.56834949462366, 82.22065653125, 77.09107972788203] [91.61852704491342, 89.84711845679011, 88.15405555868544, 86.06192840419946, 81.70347839240506, 76.55683496897163]
# [2.6012860487818713e-06, 2.6896619961862427e-06, 1.4054459714557028e-06, 7.056733869228512e-06, 1.359561826979081e-06, 2.8112137932081874e-06] [1.400996123800389e-06, 2.4376325861550252e-06, 8.35260569521916e-07, 9.034829496580471e-07, 9.447956609325972e-07, 2.5827635803001953e-06] [0.04708926038698397, 0.1227810798442231, 0.04034872089663567, 0.040984805429690525, 0.04307739337821504, 0.0714160549676668] [0.04320184742115596, 0.11661882775236007, 0.05430904994299634, 0.048374740711169255, 0.042897850814919126, 0.06896100620747535]
# 6

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Datos de entrada
wav_means = np.array(wav_means_10) * 1e-6
wav_stds = np.array(wav_stds_10) * 1e-6  # Desviaciones estándar de wav
sensor_temp = 7
pol = 1
fbg = 0
temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))# Desviaciones estándar de temperatura
print(len(temp_means))
print(len(wav_means))



# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 6
# 6
# 6
# 6
# Pendiente de la recta de ajuste en pm/K: 1.8611e+01
# Error de la pendiente en pm/K: 7.7211e-02
# 6
# Pendiente de la recta de ajuste: 1.8611e-11

# %%
# Datos de entrada
wav_means = np.array(wav_means_00) * 1e-6
wav_stds = np.array(wav_stds_00) * 1e-6  # Desviaciones estándar de wav
sensor_temp = 7
pol = 0
fbg = 0
temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))# Desviaciones estándar de temperatura
print(len(temp_means))
print(len(wav_means))



# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 6
# 6
# 6
# 6
# Pendiente de la recta de ajuste en pm/K: 1.8644e+01
# Error de la pendiente en pm/K: 3.3643e-01
# 6
# Pendiente de la recta de ajuste: 1.8644e-11

# %%
def find_plateaus(values, times, tolerance, min_plateau_length):
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        if abs(values[i] - values[start_idx]) > tolerance:
            duration = times[i - 1] - times[start_idx]

            # Convertir 'duration' de timedelta a segundos
            duration_seconds = duration.total_seconds()

            # Si la duración es suficientemente larga, guardar el plateau
            if duration_seconds >= min_plateau_length:
                segment = values[start_idx:i]

                plateaus.append({
                    "t0": times[start_idx],  # Usar directamente times[start_idx]
                    "tfin": times[i - 1],    # Usar directamente times[i - 1]
                    "duration": duration_seconds,
                    "values": segment
                })

            start_idx = i

    return plateaus


def calculate_wav_plateaus(input_filename, sensor_wav=(0, 0), params=None):
    """
    Calcula los plateaus para 'wav' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_wav: tupla (x, y) del sensor de wav a considerar.
    params: diccionario con parámetros específicos para la rama "wav".
    """
    if params is None:
        params = {
            "wav": {"tolerance": 0.2, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])

    # Filtrar los valores de 'wav' según los umbrales
    wav_ = data["wav"][:, sensor_wav[0], sensor_wav[1]]
    
    umbral_min = 1.56e-6
    umbral_max = 1.56148e-6
    mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
    
    # Filtrar los datos y los tiempos
    timestamps_filtrados = np.array(timestamps)[mask_wav]
    wav_filtrado = np.array(wav_)[mask_wav]
    
    # Ahora calculamos los plateaus para los datos filtrados de 'wav'
    wav_plateaus = find_plateaus(wav_filtrado*1e6, timestamps_filtrados, **params["wav"])
    

    
    # Define polarization and sensor labels
    polarization = "P" if sensor_wav[0] == 0 else "S"
    sensor_num = sensor_wav[1] + 1
    
    # Plot 'wav' data with plateaus
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps_filtrados, wav_filtrado*1e6, marker='o', linestyle='-', 
             label=f"Wavelength Shift (Polarization {polarization}, Sensor {sensor_num})", color="orange")
    
    for plateau in wav_plateaus:
        plt.axvline(x=plateau["t0"], color='red', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='blue', linestyle='--', alpha=0.5)
        
    plt.xlabel("Time (UTC)", fontsize=14, fontweight='bold')
    plt.ylabel("Wavelength Shift (micrometers)", fontsize=14, fontweight='bold')
    plt.title(f"Wavelength Shift Over Time with Plateaus (Polarization {polarization}, Sensor {sensor_num})", fontsize=16, fontweight='bold')
    plt.xticks(rotation=45, fontsize=12)
    plt.yticks(fontsize=12)
    plt.legend(fontsize=12)
    plt.grid()
    plt.show()
    
    # Imprimir los plateaus detectados para 'wav'
    print(f"\nPlateaus de 'wav' detectados:")
    for i, plateau in enumerate(wav_plateaus):
        print(f"Plateau {i}: t0={plateau['t0']}, "
              f"tfin={plateau['tfin']}, "
              f"mean={np.mean(plateau['values']):.6e}, std={np.std(plateau['values']):.6e}, "
              f"data_size={len(plateau['values'])}")
    
    return {"wav": wav_plateaus}


params = {
    "wav": {"tolerance": 0.000009, "min_plateau_length": 1000}
}
print(len(timestamps_filtrados), len(wav_filtrado))  # Verifica que ambas arrays tengan la misma longitud

# Ejecutar el cálculo de plateaus
wav_plateaus_result_01 = calculate_wav_plateaus("/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root", sensor_wav=(0, 1), params=params)

params = {
    "wav": {"tolerance": 0.000009, "min_plateau_length": 1000}
}

wav_plateaus_result_11 = calculate_wav_plateaus("/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root", sensor_wav=(1, 1), params=params)
# Out:
# 2416 2430
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-02-27 12:48:35, tfin=2025-02-27 13:41:45, mean=1.561174e+00, std=1.268286e-06, data_size=320
# Plateau 1: t0=2025-02-27 13:49:45, tfin=2025-02-27 14:38:35, mean=1.561135e+00, std=2.600881e-06, data_size=294
# Plateau 2: t0=2025-02-27 14:39:45, tfin=2025-02-27 15:03:05, mean=1.561100e+00, std=1.151656e-06, data_size=141
# Plateau 3: t0=2025-02-27 15:05:15, tfin=2025-02-27 15:27:35, mean=1.561066e+00, std=4.161775e-06, data_size=135
# Plateau 4: t0=2025-02-27 15:36:45, tfin=2025-02-27 15:57:25, mean=1.561054e+00, std=2.389775e-06, data_size=125
# Plateau 5: t0=2025-02-27 16:08:35, tfin=2025-02-27 16:34:45, mean=1.560968e+00, std=8.872403e-07, data_size=158
# Plateau 6: t0=2025-02-27 16:35:55, tfin=2025-02-27 17:57:15, mean=1.560868e+00, std=2.132038e-06, data_size=489
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-02-27 12:48:55, tfin=2025-02-27 13:41:45, mean=1.561174e+00, std=1.231154e-06, data_size=318
# Plateau 1: t0=2025-02-27 13:50:25, tfin=2025-02-27 14:38:35, mean=1.561137e+00, std=2.659620e-06, data_size=290
# Plateau 2: t0=2025-02-27 14:40:05, tfin=2025-02-27 15:03:15, mean=1.561100e+00, std=9.455659e-07, data_size=140
# Plateau 3: t0=2025-02-27 15:05:45, tfin=2025-02-27 15:24:55, mean=1.561064e+00, std=3.763972e-06, data_size=116
# Plateau 4: t0=2025-02-27 15:37:05, tfin=2025-02-27 15:57:25, mean=1.561053e+00, std=2.456422e-06, data_size=123
# Plateau 5: t0=2025-02-27 16:08:45, tfin=2025-02-27 16:34:35, mean=1.560968e+00, std=7.765638e-07, data_size=156
# Plateau 6: t0=2025-02-27 16:35:55, tfin=2025-02-27 17:57:05, mean=1.560869e+00, std=2.084760e-06, data_size=488

# %%
#hay que eliminar el plateau 3 de los 'wav' para que coincidan con los de temp:
temp_means_7 = [plateau["mean"] for plateau in temp_plateaus_result_7["temp"]]
temp_means_6 = [plateau["mean"] for plateau in temp_plateaus_result_6["temp"]]
wav_means_01 = [np.mean(plateau['values']) for plateau in wav_plateaus_result_01["wav"]]
wav_means_11 = [np.mean(plateau['values']) for plateau in wav_plateaus_result_11["wav"]]
#print(wav_means_01, wav_means_11, temp_means_7, temp_means_6)

# Calcular la desviación estándar de los valores en cada plateau
temp_stds_7 = [plateau["std"]  for plateau in temp_plateaus_result_7["temp"]]
temp_stds_6 = [plateau["std"] for plateau in temp_plateaus_result_6["temp"]]
wav_stds_01 = [np.std(plateau['values']) for plateau in wav_plateaus_result_01["wav"]]
wav_stds_11 = [np.std(plateau['values']) for plateau in wav_plateaus_result_11["wav"]]

# Imprimir resultados
print(wav_stds_01, wav_stds_11, temp_stds_7, temp_stds_6)

print(len(temp_stds_7))
# Out:
# [1.2682858475146149e-06, 2.60088060638522e-06, 1.1516558062721675e-06, 4.161774712018824e-06, 2.3897750976648973e-06, 8.872403100246755e-07, 2.132038231893742e-06] [1.2311540372554732e-06, 2.6596196660984577e-06, 9.455658600699764e-07, 3.763972366794142e-06, 2.456422483793537e-06, 7.765638486420647e-07, 2.084759555270823e-06] [0.04708926038698397, 0.1227810798442231, 0.04034872089663567, 0.040984805429690525, 0.04307739337821504, 0.0714160549676668] [0.04320184742115596, 0.11661882775236007, 0.05430904994299634, 0.048374740711169255, 0.042897850814919126, 0.06896100620747535]
# 6

# %%
wav_means_01 = [1.5611743693598434, 1.5611353845751959, 1.561100194713683, 1.561053599726801, 1.560967839571939, 1.5608677759805583]
wav_means_11 = [1.5611744773146063, 1.5611367173129724, 1.5611003530423808, 1.5610528537178585, 1.560967620693907, 1.5608686446342492]
wav_stds_01 = [1.2682858475146149e-06, 2.60088060638522e-06, 1.1516558062721675e-06, 4.161774712018824e-06, 8.872403100246755e-07, 2.132038231893742e-06]
wav_stds_11 = [1.2311540372554732e-06, 2.6596196660984577e-06, 9.455658600699764e-07, 3.763972366794142e-06, 7.765638486420647e-07, 2.084759555270823e-06]

# %%
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Datos de entrada
wav_means = np.array(wav_means_11) * 1e-6
wav_stds = np.array(wav_stds_11) * 1e-6  # Desviaciones estándar de wav
sensor_temp = 7
pol = 1
fbg = 1
temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))# Desviaciones estándar de temperatura
print(len(temp_means))
print(len(wav_means))



# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 6
# 6
# 6
# 6
# Pendiente de la recta de ajuste en pm/K: 2.0352e+01
# Error de la pendiente en pm/K: 2.9902e-01
# 6
# Pendiente de la recta de ajuste: 2.0352e-11

# %%
wav_means = np.array(wav_means_01) * 1e-6
wav_stds = np.array(wav_stds_01) * 1e-6  # Desviaciones estándar de wav
sensor_temp = 7
pol = 0
fbg = 1
temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))# Desviaciones estándar de temperatura
print(len(temp_means))
print(len(wav_means))



# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 6
# 6
# 6
# 6
# Pendiente de la recta de ajuste en pm/K: 2.0357e+01
# Error de la pendiente en pm/K: 2.5153e-01
# 6
# Pendiente de la recta de ajuste: 2.0357e-11

# %%
def find_plateaus(values, times, tolerance, min_plateau_length):
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        if abs(values[i] - values[start_idx]) > tolerance:
            duration = times[i - 1] - times[start_idx]

            # Convertir 'duration' de timedelta a segundos
            duration_seconds = duration.total_seconds()

            # Si la duración es suficientemente larga, guardar el plateau
            if duration_seconds >= min_plateau_length:
                segment = values[start_idx:i]

                plateaus.append({
                    "t0": times[start_idx],  # Usar directamente times[start_idx]
                    "tfin": times[i - 1],    # Usar directamente times[i - 1]
                    "duration": duration_seconds,
                    "values": segment
                })

            start_idx = i

    return plateaus


def calculate_wav_plateaus(input_filename, sensor_wav=(0, 0), params=None):
    """
    Calcula los plateaus para 'wav' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_wav: tupla (x, y) del sensor de wav a considerar.
    params: diccionario con parámetros específicos para la rama "wav".
    """
    if params is None:
        params = {
            "wav": {"tolerance": 0.2, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])

    # Filtrar los valores de 'wav' según los umbrales
    wav_ = data["wav"][:, sensor_wav[0], sensor_wav[1]]
    
    umbral_min = 1.563e-6
    umbral_max = 1.5642e-6
    mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
    
    # Filtrar los datos y los tiempos
    timestamps_filtrados = np.array(timestamps)[mask_wav]
    wav_filtrado = np.array(wav_)[mask_wav]
    
    # Ahora calculamos los plateaus para los datos filtrados de 'wav'
    wav_plateaus = find_plateaus(wav_filtrado*1e6, timestamps_filtrados, **params["wav"])
    

    
    # Define polarization and sensor labels
    polarization = "P" if sensor_wav[0] == 0 else "S"
    sensor_num = sensor_wav[1] + 1
    
    # Plot 'wav' data with plateaus
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps_filtrados, wav_filtrado*1e6, marker='o', linestyle='-', 
             label=f"Wavelength Shift (Polarization {polarization}, Sensor {sensor_num})", color="orange")
    
    for plateau in wav_plateaus:
        plt.axvline(x=plateau["t0"], color='red', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='blue', linestyle='--', alpha=0.5)
        
    plt.xlabel("Time (UTC)", fontsize=14, fontweight='bold')
    plt.ylabel("Wavelength Shift (micrometers)", fontsize=14, fontweight='bold')
    plt.title(f"Wavelength Shift Over Time with Plateaus (Polarization {polarization}, Sensor {sensor_num})", fontsize=16, fontweight='bold')
    plt.xticks(rotation=45, fontsize=12)
    plt.yticks(fontsize=12)
    plt.legend(fontsize=12)
    plt.grid()
    plt.show()
    
    # Imprimir los plateaus detectados para 'wav'
    print(f"\nPlateaus de 'wav' detectados:")
    for i, plateau in enumerate(wav_plateaus):
        print(f"Plateau {i}: t0={plateau['t0']}, "
              f"tfin={plateau['tfin']}, "
              f"mean={np.mean(plateau['values']):.6e}, std={np.std(plateau['values']):.6e}, "
              f"data_size={len(plateau['values'])}")
    
    return {"wav": wav_plateaus}


params = {
    "wav": {"tolerance": 0.000009, "min_plateau_length": 1000}
}
print(len(timestamps_filtrados), len(wav_filtrado))  # Verifica que ambas arrays tengan la misma longitud

# Ejecutar el cálculo de plateaus
wav_plateaus_result_02 = calculate_wav_plateaus("/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root", sensor_wav=(0, 2), params=params)

params = {
    "wav": {"tolerance": 0.000009, "min_plateau_length": 1000}
}

wav_plateaus_result_12 = calculate_wav_plateaus("/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250227.root", sensor_wav=(1, 2), params=params)
# Out:
# 2416 2430
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-02-27 12:47:05, tfin=2025-02-27 13:41:55, mean=1.564022e+00, std=1.605444e-06, data_size=330
# Plateau 1: t0=2025-02-27 13:52:05, tfin=2025-02-27 14:38:35, mean=1.563980e+00, std=3.021929e-06, data_size=280
# Plateau 2: t0=2025-02-27 14:40:35, tfin=2025-02-27 15:03:15, mean=1.563943e+00, std=9.309591e-07, data_size=137
# Plateau 3: t0=2025-02-27 15:36:05, tfin=2025-02-27 15:57:15, mean=1.563892e+00, std=1.346206e-06, data_size=128
# Plateau 4: t0=2025-02-27 16:07:25, tfin=2025-02-27 16:34:25, mean=1.563795e+00, std=1.007415e-06, data_size=163
# Plateau 5: t0=2025-02-27 16:36:25, tfin=2025-02-27 17:53:55, mean=1.563687e+00, std=2.125086e-06, data_size=466
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-02-27 12:48:35, tfin=2025-02-27 13:41:25, mean=1.564022e+00, std=1.086705e-06, data_size=318
# Plateau 1: t0=2025-02-27 13:47:25, tfin=2025-02-27 14:38:25, mean=1.563980e+00, std=2.837053e-06, data_size=307
# Plateau 2: t0=2025-02-27 14:39:45, tfin=2025-02-27 15:03:05, mean=1.563943e+00, std=1.123497e-06, data_size=141
# Plateau 3: t0=2025-02-27 15:04:55, tfin=2025-02-27 15:27:45, mean=1.563908e+00, std=4.603206e-06, data_size=138
# Plateau 4: t0=2025-02-27 15:36:05, tfin=2025-02-27 15:57:15, mean=1.563893e+00, std=1.264843e-06, data_size=128
# Plateau 5: t0=2025-02-27 16:07:45, tfin=2025-02-27 16:34:35, mean=1.563795e+00, std=1.045010e-06, data_size=162
# Plateau 6: t0=2025-02-27 16:36:15, tfin=2025-02-27 17:53:45, mean=1.563687e+00, std=2.085502e-06, data_size=466

# %%
#hay que eliminar el plateau 3 de los 'wav' para que coincidan con los de temp:

wav_means_02 = [np.mean(plateau['values']) for plateau in wav_plateaus_result_02["wav"]]
wav_means_12 = [np.mean(plateau['values']) for plateau in wav_plateaus_result_12["wav"]]
print(wav_means_02, wav_means_12, temp_means_7, temp_means_6)

# Calcular la desviación estándar de los valores en cada plateau

wav_stds_02 = [np.std(plateau['values']) for plateau in wav_plateaus_result_02["wav"]]
wav_stds_12 = [np.std(plateau['values']) for plateau in wav_plateaus_result_12["wav"]]

# Imprimir resultados
print(wav_stds_02, wav_stds_12)
# Out:
# [1.5640215224591594, 1.563980341030149, 1.5639425664258435, 1.5638922426030841, 1.5637953787038503, 1.5636867279037865] [1.564021767722377, 1.5639804285851568, 1.5639429866591403, 1.5639077080503747, 1.5638926116399874, 1.5637954570741328, 1.5636867328456616] [92.12836531893004, 90.35065674328858, 88.65816638968825, 86.56834949462366, 82.22065653125, 77.09107972788203] [91.61852704491342, 89.84711845679011, 88.15405555868544, 86.06192840419946, 81.70347839240506, 76.55683496897163]
# [1.6054437285441712e-06, 3.0219289632741926e-06, 9.309591343481194e-07, 1.3462064264107025e-06, 1.0074154346067828e-06, 2.1250862802247233e-06] [1.0867045859322812e-06, 2.8370526546459692e-06, 1.1234972192903266e-06, 4.603205885565903e-06, 1.2648428020963417e-06, 1.04500957125508e-06, 2.085501758404371e-06]

# %%
wav_means_12 = [1.564021767722377, 1.5639804285851568, 1.5639429866591403, 1.5638926116399874, 1.5637954570741328, 1.5636867328456616]
wav_stds_12 = [1.0867045859322812e-06, 2.8370526546459692e-06, 1.1234972192903266e-06, 1.2648428020963417e-06, 1.04500957125508e-06, 2.085501758404371e-06]

# %%
wav_means = np.array(wav_means_02) * 1e-6
wav_stds = np.array(wav_stds_02) * 1e-6  # Desviaciones estándar de wav
sensor_temp = 7
pol = 0
fbg = 2
temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))# Desviaciones estándar de temperatura
print(len(temp_means))
print(len(wav_means))



# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 6
# 6
# 6
# 6
# Pendiente de la recta de ajuste en pm/K: 2.2320e+01
# Error de la pendiente en pm/K: 2.2429e-01
# 6
# Pendiente de la recta de ajuste: 2.2320e-11

# %%
wav_means = np.array(wav_means_12) * 1e-6
wav_stds = np.array(wav_stds_12) * 1e-6  # Desviaciones estándar de wav
sensor_temp = 7
pol = 1
fbg = 2
temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))# Desviaciones estándar de temperatura
print(len(temp_means))
print(len(wav_means))



# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)
# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 6
# 6
# 6
# 6
# Pendiente de la recta de ajuste en pm/K: 2.2337e+01
# Error de la pendiente en pm/K: 2.2049e-01
# 6
# Pendiente de la recta de ajuste: 2.2337e-11

# %% [markdown]
# # **SUMMARY: PEEK-7 Fiber Thermal Sensitivity Results**
#
# This notebook analyzed the thermal sensitivity of the PEEK-7 fiber with 3 FBG sensors at 2 polarization states each.
#
# **Experiment Date**: February 27, 2025
# **ROOT File**: `resampled20250227.root`
# **Analysis Method**: Linear regression between wavelength shifts and temperature changes
#
# ---

# %%
import numpy as np

# PEEK-7 Thermal Sensitivity Results
# Values obtained from linear fits throughout this notebook
# FBG indexing: fbg=0 is Sensor 1, fbg=1 is Sensor 2, fbg=2 is Sensor 3
# Polarization: pol=0 is P, pol=1 is S

# Data: Sensor, Polarization, Sensitivity (m/K), Sensitivity (pm/K)
results = [
    (1, 'S', 1.8611e-11, 18.611),  # fbg=0, pol=1
    (1, 'P', 1.8644e-11, 18.644),  # fbg=0, pol=0
    (2, 'S', 2.0352e-11, 20.352),  # fbg=1, pol=1
    (2, 'P', 2.0357e-11, 20.357),  # fbg=1, pol=0
    (3, 'P', 2.2320e-11, 22.320),  # fbg=2, pol=0
    (3, 'S', 2.2337e-11, 22.337)   # fbg=2, pol=1
]

# Extract sensitivity values in pm/K for statistics
sensitivities = np.array([r[3] for r in results])

print("=" * 70)
print("PEEK-7 FIBER THERMAL SENSITIVITY SUMMARY")
print("=" * 70)
print(f"{'Sensor':<8} {'Pol':<6} {'Sensitivity (m/K)':<20} {'Sensitivity (pm/K)':<20}")
print("-" * 70)
for sensor, pol, sens_m, sens_pm in results:
    print(f"{sensor:<8} {pol:<6} {sens_m:<20.4e} {sens_pm:<20.3f}")
print("=" * 70)
print(f"\nMean sensitivity: {sensitivities.mean():.3f} ± {sensitivities.std():.3f} pm/K")
print(f"Range: {sensitivities.min():.3f} - {sensitivities.max():.3f} pm/K")
print(f"Coefficient of variation: {(sensitivities.std() / sensitivities.mean() * 100):.2f}%")
print("\nAll fits show excellent linearity with R² > 0.99")
# Out:
# ======================================================================
# PEEK-7 FIBER THERMAL SENSITIVITY SUMMARY
# ======================================================================
# Sensor   Pol    Sensitivity (m/K)    Sensitivity (pm/K)
# ----------------------------------------------------------------------
# 1        S      1.8611e-11           18.611
# 1        P      1.8644e-11           18.644
# 2        S      2.0352e-11           20.352
# 2        P      2.0357e-11           20.357
# 3        P      2.2320e-11           22.320
# 3        S      2.2337e-11           22.337
# ======================================================================
#
# Mean sensitivity: 20.437 ± 1.512 pm/K
# Range: 18.611 - 22.337 pm/K
# Coefficient of variation: 7.40%
#
# All fits show excellent linearity with R² > 0.99
