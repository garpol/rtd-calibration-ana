# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime
from IPython.display import display

# Archivo ROOT de entrada
input_filename = "/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250310.root"

# Abrir el archivo ROOT con uproot
with uproot.open(input_filename) as file:
    tree = file["resampled_data"]  # nombre correcto del árbol
    data = tree.arrays(library="np")  # Devuelve un diccionario de numpy arrays

# Extraer tiempos y valores
times = data["t"]
press = data["press"]
temp = data["temp"]

# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# ========== ELEGANT PRESSURE PLOT ==========
fig = plt.figure(figsize=(12, 6))
ax = fig.add_subplot(111)

# Plot pressure with professional styling - solid blue, all points equally visible
ax.plot(timestamps, press, color='#0066cc', linewidth=2.5, marker='o', markersize=7, 
        markerfacecolor='#0066cc', markeredgecolor='#0066cc', label='Pressure')

# Title and labels - bold and clear
ax.set_title('Pressure Evolution During FBG Sensitivity Test\nMarch 10, 2025', 
             fontsize=16, fontweight='bold', pad=20)
ax.set_xlabel('Time (UTC)', fontsize=13, fontweight='bold')
ax.set_ylabel('Pressure (bar)', fontsize=13, fontweight='bold')

# Grid for better readability
ax.grid(True, alpha=0.3, linestyle='--', linewidth=0.8, which='both')
ax.set_axisbelow(True)

# Rotate x-axis labels for better readability
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45, ha='right')

# Tick parameters
ax.tick_params(axis='both', labelsize=11, direction='out', length=6, width=1.5)

# Add statistics box (top right)
press_array = np.array(press)
press_min = press_array.min()
press_max = press_array.max()
press_mean = press_array.mean()
press_range = press_max - press_min
stats_text = f'Min: {press_min:.2f} bar\nMax: {press_max:.2f} bar\nMean: {press_mean:.2f} bar\nΔP: {press_range:.2f} bar'
ax.text(0.98, 0.98, stats_text, transform=ax.transAxes, 
        fontsize=10, verticalalignment='top', horizontalalignment='right',
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.9, edgecolor='#2c3e50', linewidth=2))

# Legend
ax.legend(loc='upper left', fontsize=11, framealpha=0.95, edgecolor='#2c3e50', fancybox=True)

# Tight layout
fig.tight_layout()
display(fig)
plt.close()

print(f"✅ Pressure plot generated")
print(f"   Pressure range: {press_min:.2f} - {press_max:.2f} bar")
print(f"   Total measurement points: {len(press)}")
# Out:
# ✅ Pressure plot generated
#    Pressure range: -0.14 - 3.34 bar
#    Total measurement points: 2251

# %%
# Extraer tiempos y valores de wav[0][0]
wav_ = data["wav"][:, 0, 0]  
# Filtrar los datos y los tiempos
umbral_min = 1.5574e-6
umbral_max = 1.5580e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav]   
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]
# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_00')
plt.xlabel("Time (UTC)")
plt.ylabel("Wavelength (m)")
plt.title("Peaks 10.03.25")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# ExtraeR valores de wav[1][0]
wav_ = data["wav"][:, 1, 0]  
# Filtrar los datos y los tiempos
umbral_min = 1.5574e-6
umbral_max = 1.5580e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav] 
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]
# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_10')
plt.xlabel("Time (UTC)")
plt.ylabel("Wavelength (m)")
plt.title("Peaks 10.03.25")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
# Extraer tiempos y valores de wav[0][1]
wav_ = data["wav"][:, 0, 1]  # Accede correctamente a los datos
# Filtrar los datos y los tiempos
umbral_min = 1.56e-6
umbral_max = 1.56148e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav]
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]
# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_01')
plt.xlabel("Time (UTC)")
plt.ylabel("Wavelength (m)")
plt.title("Peaks 10.03.25")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# Extraer tiempos y valores de wav[1][1]
wav_ = data["wav"][:, 1, 1]  # Accede correctamente a los datos
# Filtrar los datos y los tiempos
umbral_min = 1.56e-6
umbral_max = 1.56148e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav]
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]
# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_11')
plt.xlabel("Time (UTC)")
plt.ylabel("Wavelength (m)")
plt.title("Peaks 10.03.25")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
# Extraer tiempos y valores de wav[0][2]
wav_ = data["wav"][:, 0, 2]  # Accede correctamente a los datos
# Filtrar los datos y los tiempos
umbral_min = 1.563e-6
umbral_max = 1.5642e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav]
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]
# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_02')
plt.xlabel("Time (UTC)")
plt.ylabel("Wavelength (m)")
plt.title("Peaks 10.03.25")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# Extraer tiempos y valores de wav[1][2]
wav_ = data["wav"][:, 1, 2]  # Accede correctamente a los datos
# Filtrar los datos y los tiempos
umbral_min = 1.563e-6
umbral_max = 1.5642e-6
mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
timestamps_filtrados = np.array(timestamps)[mask_wav]
wav_filtrado = np.array(wav_)[mask_wav]
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]
# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_filtrado, marker='o', linestyle='-', label='wav_12')
plt.xlabel("Time (UTC)")
plt.ylabel("Wavelength (m)")
plt.title("Peaks 10.03.25")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
times = data["t"] # a lo mejor hay que borrar esta línea de código
# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# 🔹 Graficar las temperaturas de los sensores de fuera de la cápsula
plt.figure(figsize=(10, 5))
for i in range(4):  # Hay 8 sensores pero solo 4 miden la temperatura fuera, otros 2 están dentro de la cápsula 
    plt.plot(timestamps, temp[:, i], marker='o', linestyle='-', label=f'Temp Sensor {i+1}')
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (K)")
plt.title("4 first RTD Sensors Temperature")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# 🔹 Graficar SOLO el sensor 2 (índice 1)
sensor_id = 7  # Seleccionar el ultimo sensor (índice 7)

plt.figure(figsize=(10, 5))
plt.plot(timestamps, temp[:, sensor_id], marker='o', linestyle='-', color='r', label=f'Temp Sensor {sensor_id + 1}')
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (K)")
plt.title(f"RTD {sensor_id + 1} Temperature")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
# 🔹 FILTRAR desde las 14:00 UTC
timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])
mask = np.array([t.hour >= 14 for t in timestamps])  # Solo datos con hora >= 14 (cambiarlo según el run)
timestamps_filtrados = timestamps[mask]
temp_filtrado = temp[mask]  # Filtramos también los valores de temperatura

# 🔹 Graficar las temperaturas filtradas
plt.figure(figsize=(10, 5))
for i in range(4):  # Hay 8 sensores pero solo 4 miden la temperatura dentro 
    plt.plot(timestamps_filtrados, temp_filtrado[:, i], marker='o', linestyle='-', label=f'Temp Sensor {i+1}')
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (K)")
plt.title("4 first RTD Sensors Temperature (≥ 14:00 UTC)")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# 🔹 Graficar SOLO el sensor 8 (índice 7) filtrado
sensor_id = 7

plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, temp_filtrado[:, sensor_id], marker='o', linestyle='-', color='r', label=f'Temp Sensor {sensor_id + 1}')
plt.xlabel("Time (UTC)")
plt.ylabel("Temperature (K)")
plt.title(f"RTD {sensor_id + 1} Temperature (≥ 14:00 UTC)")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()

# %%
# Verificar la estructura de "wav"
print(data.keys())  # Verifica las variables en el árbol
if "wav" in data:
    print(f"Shape de 'wav': {data['wav'].shape}")  # Confirmar la estructura

# Extraer tiempos y valores de la polarización 'p' (x=1) del primer sensor (y=0)
times = data["t"]
wav_00_p = data["wav"][:, 0, 0]  # Polarización 'p', Sensor 0

# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

# Definir los umbrales
umbral_min = 1.5574e-6
umbral_max = 1.5580e-6

# Aplicar máscara de filtrado
mask = (wav_00_p > umbral_min) & (wav_00_p < umbral_max)

# Filtrar datos
timestamps_filtrados = np.array(timestamps)[mask]
wav_00_p_filtrado = wav_00_p[mask]


# Graficar
plt.figure(figsize=(10, 5))
plt.plot(timestamps_filtrados, wav_00_p_filtrado, marker='o', linestyle='-', label="wav['p'][0] Filtrado")  
plt.xlabel("Tiempo (UTC)")
plt.ylabel("wav[0][0]")
plt.title("Gráfico de wav[0][0] vs Tiempo")
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()
# Out:
# dict_keys(['t', 'wav', 'temp', 'press'])
# Shape de 'wav': (2251, 2, 3)

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

def find_plateaus(values, times, tolerance=0.01, min_plateau_length=500):
    """
    Encuentra plateaus en los datos.
    - values: array de valores.
    - times: array de tiempos (segundos desde el epoch).
    - tolerance: diferencia máxima para considerar un plateau.
    - min_plateau_length: duración mínima del plateau en segundos.
    """
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        if abs(values[i] - values[start_idx]) > tolerance:
            duration = times[i - 1] - times[start_idx]
            if duration >= min_plateau_length:
                segment = values[start_idx:i]
                plateaus.append({
                    "t0": times[start_idx],
                    "tfin": times[i - 1],
                    "mean": np.mean(segment),
                    "std": np.std(segment),
                    "data": segment
                })
            start_idx = i  # Reiniciar seguimiento
    
    return plateaus

def calculate_plateaus(input_filename, sensor_temp=0, sensor_wav=(0, 0), params=None):
    """
    Calcula los plateaus para 'press', 'temp' y 'wav' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_temp: índice del sensor de temperatura a considerar.
    sensor_wav: tupla (x, y) del sensor de wav a considerar.
    params: diccionario con parámetros específicos para cada rama {"press": {...}, "temp": {...}, "wav": {...}}
    """
    if params is None:
        params = {
            "press": {"tolerance": 0.01, "min_plateau_length": 500},
            "temp": {"tolerance": 0.01, "min_plateau_length": 500},
            "wav": {"tolerance": 0.01, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])
    
    press_plateaus = find_plateaus(data['press'], times, **params["press"])
    temp_plateaus = find_plateaus([row[sensor_temp] for row in data['temp']], times, **params["temp"])

    # Filtrar los valores de 'wav' según los umbrales
    wav_ = [row[sensor_wav[0]][sensor_wav[1]] for row in data['wav']]
    umbral_min = 1.5574e-6
    umbral_max = 1.5580e-6
    mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
    
    # Filtrar los datos y los tiempos
    timestamps_filtrados = np.array(timestamps)[mask_wav]
    wav_filtrado = np.array(wav_)[mask_wav]
    
    # Ahora calculamos los plateaus para los datos filtrados de 'wav'
    wav_plateaus = find_plateaus(wav_filtrado*1e6, timestamps_filtrados, **params["wav"])
    
    # Graficar los datos con los plateaus por separado
    for branch, series, plateaus, color in zip(["press", "temp", "wav"],
                                                [data['press'], [row[sensor_temp] for row in data['temp']], wav_filtrado*1e6],
                                                [press_plateaus, temp_plateaus, wav_plateaus],
                                                ["blue", "green", "orange"]):
        plt.figure(figsize=(10, 5))
        if branch == "wav":
            # En el caso de 'wav', utilizamos los tiempos y valores filtrados
            plt.plot(timestamps_filtrados, series, marker='o', linestyle='-', label=branch, color=color)
        else:
            # Para 'press' y 'temp', se grafican con los tiempos originales
            plt.plot(timestamps, series, marker='o', linestyle='-', label=branch, color=color)
        
        for plateau in plateaus:
            plt.axvline(x=datetime.datetime.utcfromtimestamp(plateau["t0"]), color='red', linestyle='--', alpha=0.5)
            plt.axvline(x=datetime.datetime.utcfromtimestamp(plateau["tfin"]), color='blue', linestyle='--', alpha=0.5)
        
        plt.xlabel("Time (UTC)")
        plt.ylabel(branch)
        plt.title(f"{branch} vs Time with Plateaus")
        plt.xticks(rotation=45)
        plt.legend()
        plt.grid()
        plt.show()
    
    # Imprimir plateaus de cada rama
    for branch, plateaus in {"press": press_plateaus, "temp": temp_plateaus, "wav": wav_plateaus}.items():
        print(f"\nPlateaus de {branch} detectados:")
        for i, plateau in enumerate(plateaus):
            print(f"Plateau {i}: t0={datetime.datetime.utcfromtimestamp(plateau['t0'])}, "
                  f"tfin={datetime.datetime.utcfromtimestamp(plateau['tfin'])}, "
                  f"mean={plateau['mean']:.6e}, std={plateau['std']:.6e}, "
                  f"data_size={len(plateau['data'])}")
    
    return {"press": press_plateaus, "temp": temp_plateaus, "wav": wav_plateaus}

params = {
    "press": {"tolerance": 0.25, "min_plateau_length": 1000},
    "temp": {"tolerance": 0.5, "min_plateau_length": 800},
    "wav": {"tolerance": 1e-2, "min_plateau_length": 1000}
}

# Ejecutar el cálculo de plateaus
plateaus_result = calculate_plateaus(input_filename, sensor_temp=7, sensor_wav=(0, 0), params=params)

#para wav lo hacemos a parte porque la tolerancia es de 1e-5 y da fallos si no cambiamos la estructura de tiempos
# Out:
# Plateaus de press detectados:
# Plateau 0: t0=2025-03-10 12:10:01, tfin=2025-03-10 13:32:51, mean=-1.210406e-01, std=1.658862e-02, data_size=498
# Plateau 1: t0=2025-03-10 13:39:41, tfin=2025-03-10 14:39:51, mean=3.223823e+00, std=2.643971e-02, data_size=362
# Plateau 2: t0=2025-03-10 14:40:01, tfin=2025-03-10 15:17:01, mean=3.303423e+00, std=2.226450e-02, data_size=223
# Plateau 3: t0=2025-03-10 15:19:31, tfin=2025-03-10 15:55:21, mean=2.642092e+00, std=4.764569e-02, data_size=216
# Plateau 4: t0=2025-03-10 16:02:01, tfin=2025-03-10 16:35:51, mean=2.004284e+00, std=3.355281e-02, data_size=204
# Plateau 5: t0=2025-03-10 16:36:01, tfin=2025-03-10 17:03:51, mean=1.646841e+00, std=2.267792e-02, data_size=168
# Plateau 6: t0=2025-03-10 17:05:21, tfin=2025-03-10 17:40:21, mean=8.493081e-01, std=5.328753e-02, data_size=211
# Plateau 7: t0=2025-03-10 17:51:21, tfin=2025-03-10 18:13:11, mean=3.739764e-01, std=6.213297e-02, data_size=132
#
# Plateaus de temp detectados:
# ...

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

def find_plateaus(values, times, tolerance, min_plateau_length):
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        if abs(values[i] - values[start_idx]) > tolerance:
            duration = times[i - 1] - times[start_idx]

            # Convertir 'duration' de timedelta a segundos
            duration_seconds = duration.total_seconds()

            # Si la duración es suficientemente larga, guardar el plateau
            if duration_seconds >= min_plateau_length:
                segment = values[start_idx:i]

                plateaus.append({
                    "t0": times[start_idx],  # Usar directamente times[start_idx]
                    "tfin": times[i - 1],    # Usar directamente times[i - 1]
                    "duration": duration_seconds,
                    "values": segment
                })

            start_idx = i

    return plateaus

def calculate_wav_plateaus(input_filename, sensor_wav=(0, 0), params=None):
    """
    Calcula los plateaus para 'wav' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_wav: tupla (x, y) del sensor de wav a considerar.
    params: diccionario con parámetros específicos para la rama "wav".
    """
    if params is None:
        params = {
            "wav": {"tolerance": 0.2, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])

    # Filtrar los valores de 'wav' según los umbrales
    wav_ = data["wav"][:, sensor_wav[0], sensor_wav[1]]
    umbral_min = 1.5574e-6
    umbral_max = 1.5580e-6
    mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
    
    # Filtrar los datos y los tiempos
    timestamps_filtrados = np.array(timestamps)[mask_wav]
    wav_filtrado = np.array(wav_)[mask_wav]
    
    # Ahora calculamos los plateaus para los datos filtrados de 'wav'
    wav_plateaus = find_plateaus(wav_filtrado*1e6, timestamps_filtrados, **params["wav"])
    
    # Graficar los datos de 'wav' con los plateaus
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps_filtrados, wav_filtrado*1e6, marker='o', linestyle='-', label="wav", color="orange")
    
    for plateau in wav_plateaus:
        plt.axvline(x=plateau["t0"], color='red', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='blue', linestyle='--', alpha=0.5)
    
    plt.xlabel("Time (UTC)")
    plt.ylabel("wav x 10^6")
    plt.title("wav vs Time with Plateaus")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid()
    plt.show()
    
    # Imprimir los plateaus detectados para 'wav'
    print(f"\nPlateaus de 'wav' detectados:")
    for i, plateau in enumerate(wav_plateaus):
        print(f"Plateau {i}: t0={plateau['t0']}, "
              f"tfin={plateau['tfin']}, "
              f"mean={np.mean(plateau['values']):.6e}, std={np.std(plateau['values']):.6e}, "
              f"data_size={len(plateau['values'])}")
    
    return {"wav": wav_plateaus}


params = {
    "wav": {"tolerance": 0.000015, "min_plateau_length": 1000}
}
print(len(timestamps_filtrados), len(wav_filtrado))  # Verifica que ambas arrays tengan la misma longitud

# Ejecutar el cálculo de plateaus
wav_plateaus_result_00 = calculate_wav_plateaus(input_filename, sensor_wav=(0, 0), params=params)

params = {
    "wav": {"tolerance": 0.000008, "min_plateau_length": 1000}
}


wav_plateaus_result_10 = calculate_wav_plateaus(input_filename, sensor_wav=(1, 0), params=params)
# Out:
# 1407 1408
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-03-10 12:16:01, tfin=2025-03-10 12:41:01, mean=1.557612e+00, std=3.660863e-06, data_size=150
# Plateau 1: t0=2025-03-10 13:40:41, tfin=2025-03-10 14:16:41, mean=1.557911e+00, std=2.867371e-06, data_size=217
# Plateau 2: t0=2025-03-10 14:21:21, tfin=2025-03-10 14:55:41, mean=1.557872e+00, std=2.463005e-06, data_size=206
# Plateau 3: t0=2025-03-10 14:58:41, tfin=2025-03-10 15:33:21, mean=1.557831e+00, std=1.634197e-06, data_size=205
# Plateau 4: t0=2025-03-10 15:33:31, tfin=2025-03-10 16:00:51, mean=1.557806e+00, std=1.934066e-06, data_size=164
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-03-10 12:16:01, tfin=2025-03-10 12:39:41, mean=1.557610e+00, std=2.450677e-06, data_size=143
# Plateau 1: t0=2025-03-10 13:40:51, tfin=2025-03-10 14:15:51, mean=1.557910e+00, std=1.604530e-06, data_size=211
# Plateau 2: t0=2025-03-10 14:23:41, tfin=2025-03-10 14:54:21, mean=1.557871e+00, std=1.807378e-06, data_size=185
# ...

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

def find_plateaus(values, times, tolerance=0.01, min_plateau_length=500):
    """
    Encuentra plateaus en los datos considerando una tolerancia relativa (% de los valores).
    
    Parámetros:
    - values: array de valores.
    - times: array de tiempos (segundos desde el epoch).
    - tolerance: porcentaje máximo de variación permitido en el plateau (ej. 0.01 = 1%).
    - min_plateau_length: duración mínima del plateau en segundos.
    
    Retorna:
    - Lista de plateaus detectados con su tiempo de inicio, fin, media y desviación estándar.
    """
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        # Tolerancia relativa basada en el primer valor del plateau
        threshold = abs(values[start_idx]) * tolerance  

        # Si la variación supera el % permitido, cerramos el plateau
        if abs(values[i] - values[start_idx]) > threshold:
            duration_seconds = (times[i - 1] - times[start_idx]).total_seconds()
            
            if duration_seconds >= min_plateau_length:
                segment = values[start_idx:i]
                plateaus.append({
                    "t0": times[start_idx],
                    "tfin": times[i - 1],
                    "mean": np.mean(segment),
                    "std": np.std(segment),
                    "data": segment
                })
            
            start_idx = i  # Reiniciar búsqueda de un nuevo plateau
    
    return plateaus

def calculate_temp_plateaus(input_filename, sensor_temp=0, params=None):
    """
    Calcula los plateaus para 'temp' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_temp: índice del sensor de temperatura a considerar.
    params: diccionario con parámetros específicos para cada rama {"temp": {...}}
    """
    if params is None:
        params = {
            "temp": {"tolerance": 0.01, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])
    
    # Filtro de tiempo: Seleccionar solo los datos a partir de las 14:00 (hora UTC)
    filter_time = datetime.time(13, 46)  # 14:00 UTC
    timestamps_filtrados = [t for t in timestamps if t.time() >= filter_time]
    temp_filtrado = [row[sensor_temp] for row, t in zip(data['temp'], timestamps) if t in timestamps_filtrados]

    # Calculamos los plateaus de los datos filtrados de temperatura
    temp_plateaus = find_plateaus(temp_filtrado, timestamps_filtrados, **params["temp"])

    # Graficar los datos de temperatura con los plateaus
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps_filtrados, temp_filtrado, marker='o', linestyle='-', label="Temperature", color="green")
    
    for plateau in temp_plateaus:
        plt.axvline(x=plateau["t0"], color='red', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='blue', linestyle='--', alpha=0.5)
    
    plt.xlabel("Time (UTC)")
    plt.ylabel("Temperature")
    plt.title(f"Temperature vs Time with Plateaus (Sensor {sensor_temp})")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid()
    plt.show()
    
    # Imprimir plateaus de temperatura
    print(f"\nPlateaus de temperatura detectados:")
    for i, plateau in enumerate(temp_plateaus):
        print(f"Plateau {i}: t0={plateau['t0']}, "
              f"tfin={plateau['tfin']}, "
              f"mean={plateau['mean']:.6e}, std={plateau['std']:.6e}, "
              f"data_size={len(plateau['data'])}")
    
    return {"temp": temp_plateaus}

params = {
    "temp": {"tolerance": 0.005, "min_plateau_length": 1000}   
}

# Ejecutar el cálculo de plateaus
temp_plateaus_result_7 = calculate_temp_plateaus(input_filename, sensor_temp=7, params=params)

params = {
    "temp": {"tolerance": 0.003, "min_plateau_length": 1000}   
}

temp_plateaus_result_6 = calculate_temp_plateaus(input_filename, sensor_temp=6, params=params)
# Out:
# Plateaus de temperatura detectados:
# Plateau 0: t0=2025-03-10 14:39:31, tfin=2025-03-10 15:16:11, mean=9.232195e+01, std=7.722616e-02, data_size=221
# Plateau 1: t0=2025-03-10 15:20:51, tfin=2025-03-10 15:42:21, mean=9.039362e+01, std=1.149824e-01, data_size=130
# Plateau 2: t0=2025-03-10 16:00:51, tfin=2025-03-10 16:33:01, mean=8.818311e+01, std=5.139755e-02, data_size=194
# Plateau 3: t0=2025-03-10 16:38:21, tfin=2025-03-10 17:01:31, mean=8.677107e+01, std=3.958202e-02, data_size=140
# Plateaus de temperatura detectados:
# Plateau 0: t0=2025-03-10 14:39:41, tfin=2025-03-10 15:15:51, mean=9.181924e+01, std=4.894713e-02, data_size=218
# Plateau 1: t0=2025-03-10 15:26:01, tfin=2025-03-10 15:51:21, mean=8.980519e+01, std=6.757993e-02, data_size=153
# Plateau 2: t0=2025-03-10 15:59:31, tfin=2025-03-10 16:33:01, mean=8.767701e+01, std=4.525911e-02, data_size=202
# Plateau 3: t0=2025-03-10 16:40:21, tfin=2025-03-10 17:01:31, mean=8.626445e+01, std=3.748945e-02, data_size=128

# %%
temp_means_7 = [plateau["mean"] for plateau in temp_plateaus_result_7["temp"]]
temp_means_6 = [plateau["mean"] for plateau in temp_plateaus_result_6["temp"]]
wav_means_00 = [np.mean(plateau['values']) for plateau in wav_plateaus_result_00["wav"]]
wav_means_10 = [np.mean(plateau['values']) for plateau in wav_plateaus_result_10["wav"]]
#print(wav_means_00, wav_means_10, temp_means_7, temp_means_6)

# Calcular la desviación estándar de los valores en cada plateau
temp_stds_7 = [plateau["std"]  for plateau in temp_plateaus_result_7["temp"]]
temp_stds_6 = [plateau["std"] for plateau in temp_plateaus_result_6["temp"]]
wav_stds_00 = [np.std(plateau['values']) for plateau in wav_plateaus_result_00["wav"]]
wav_stds_10 = [np.std(plateau['values']) for plateau in wav_plateaus_result_10["wav"]]

# Imprimir resultados
print(wav_stds_00, wav_stds_10, temp_stds_7, temp_stds_6)

#print(len(temp_stds_7))
# Out:
# [3.6608630380700127e-06, 2.8673713010390946e-06, 2.4630045241930645e-06, 1.6341967909433336e-06, 1.9340662480127235e-06] [2.450676834584319e-06, 1.6045296528856513e-06, 1.8073781106070832e-06, 9.833640596106052e-07, 7.359481073105717e-07] [0.07722616291943513, 0.11498244739561457, 0.051397554656651245, 0.03958202123445372] [0.048947130957406736, 0.06757993208243783, 0.0452591144834916, 0.037489445439654955]

# %%
#eliminamos el primer plateau de wav para que haya 4, como de temperatura
wav_means_00 = [1.5579112984155612, 1.5578720562271133, 1.5578305754949167, 1.5578056709771657]
wav_means_10 = [1.5579104268239332, 1.5578705179692314, 1.5578300551696247, 1.557804303046035]
wav_stds_00 = [2.8673713010390946e-06, 2.4630045241930645e-06, 1.6341967909433336e-06, 1.9340662480127235e-06]
wav_stds_10 = [1.6045296528856513e-06, 1.8073781106070832e-06, 9.833640596106052e-07, 7.359481073105717e-07]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Datos de entrada
wav_means = np.array(wav_means_10) * 1e-6
wav_stds = np.array(wav_stds_10) * 1e-6  # Desviaciones estándar de wav

##CAMBIAR ESTOS DATOS PARA ELEGIR SENSOR Y POLARIZACIÓN DEL FIT:
sensor_temp = 7
pol = 1
fbg = 0

temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))
print(len(temp_means))
print(len(wav_means))


# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 4
# 4
# 4
# 4
# Pendiente de la recta de ajuste en pm/K: 1.9038e+01
# Error de la pendiente en pm/K: 4.1244e-01
# 4
# Pendiente de la recta de ajuste: 1.9038e-11

# %%
# Datos de entrada
wav_means = np.array(wav_means_00) * 1e-6
wav_stds = np.array(wav_stds_00) * 1e-6  # Desviaciones estándar de wav
sensor_temp = 7
pol = 0
fbg = 0
temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))# Desviaciones estándar de temperatura
print(len(temp_means))
print(len(wav_means))



# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 4
# 4
# 4
# 4
# Pendiente de la recta de ajuste en pm/K: 1.9025e+01
# Error de la pendiente en pm/K: 3.8321e-01
# 4
# Pendiente de la recta de ajuste: 1.9025e-11

# %%
def find_plateaus(values, times, tolerance=0.01, min_plateau_length=500):
    """
    Encuentra plateaus en los datos considerando una tolerancia relativa (% de los valores).
    
    Parámetros:
    - values: array de valores.
    - times: array de tiempos (segundos desde el epoch).
    - tolerance: porcentaje máximo de variación permitido en el plateau (ej. 0.01 = 1%).
    - min_plateau_length: duración mínima del plateau en segundos.
    
    Retorna:
    - Lista de plateaus detectados con su tiempo de inicio, fin, media y desviación estándar.
    """
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        # Tolerancia relativa basada en el primer valor del plateau
        threshold = abs(values[start_idx]) * tolerance  

        # Si la variación supera el % permitido, cerramos el plateau
        if abs(values[i] - values[start_idx]) > threshold:
            duration_seconds = (times[i - 1] - times[start_idx]).total_seconds()
            
            if duration_seconds >= min_plateau_length:
                segment = values[start_idx:i]
                plateaus.append({
                    "t0": times[start_idx],
                    "tfin": times[i - 1],
                    "mean": np.mean(segment),
                    "std": np.std(segment),
                    "data": segment
                })
            
            start_idx = i  # Reiniciar búsqueda de un nuevo plateau
    
    return plateaus


def calculate_wav_plateaus(input_filename, sensor_wav=(0, 0), params=None):
    """
    Calcula los plateaus para 'wav' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_wav: tupla (x, y) del sensor de wav a considerar.
    params: diccionario con parámetros específicos para la rama "wav".
    """
    if params is None:
        params = {
            "wav": {"tolerance": 0.2, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])

    # Filtrar los valores de 'wav' según los umbrales
    wav_ = data["wav"][:, sensor_wav[0], sensor_wav[1]]
    
    umbral_min = 1.56e-6
    umbral_max = 1.56148e-6
    mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
    
    # Filtrar los datos y los tiempos
    timestamps_filtrados = np.array(timestamps)[mask_wav]
    wav_filtrado = np.array(wav_)[mask_wav]
    
    # Ahora calculamos los plateaus para los datos filtrados de 'wav'
    wav_plateaus = find_plateaus(wav_filtrado*1e6, timestamps_filtrados, **params["wav"])
    

    
    # Define polarization and sensor labels
    polarization = "P" if sensor_wav[0] == 0 else "S"
    sensor_num = sensor_wav[1] + 1
    
    # Plot 'wav' data with plateaus
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps_filtrados, wav_filtrado*1e6, marker='o', linestyle='-', 
             label=f"Wavelength Shift (Polarization {polarization}, Sensor {sensor_num})", color="orange")
    
    for plateau in wav_plateaus:
        plt.axvline(x=plateau["t0"], color='red', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='blue', linestyle='--', alpha=0.5)
        
    plt.xlabel("Time (UTC)", fontsize=14, fontweight='bold')
    plt.ylabel("Wavelength Shift (micrometers)", fontsize=14, fontweight='bold')
    plt.title(f"Wavelength Shift Over Time with Plateaus (Polarization {polarization}, Sensor {sensor_num})", fontsize=16, fontweight='bold')
    plt.xticks(rotation=45, fontsize=12)
    plt.yticks(fontsize=12)
    plt.legend(fontsize=12)
    plt.grid()
    plt.show()
    
    # Imprimir los plateaus detectados para 'wav'
    print(f"\nPlateaus de 'wav' detectados:")
    for i, plateau in enumerate(wav_plateaus):
        print(f"Plateau {i}: t0={plateau['t0']}, "
              f"tfin={plateau['tfin']}, "
              f"mean={np.mean(plateau['data']):.6e}, std={np.std(plateau['data']):.6e}, "
              f"data_size={len(plateau['data'])}")
    
    return {"wav": wav_plateaus}


params = {
    "wav": {"tolerance": 0.00001, "min_plateau_length": 1000}
}
print(len(timestamps_filtrados), len(wav_filtrado))  # Verifica que ambas arrays tengan la misma longitud

# Ejecutar el cálculo de plateaus
wav_plateaus_result_01 = calculate_wav_plateaus(input_filename, sensor_wav=(0, 1), params=params)

params = {
    "wav": {"tolerance": 0.00001, "min_plateau_length": 1000}
}

wav_plateaus_result_11 = calculate_wav_plateaus(input_filename, sensor_wav=(1, 1), params=params)
# Out:
# 1407 1408
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-03-10 12:16:01, tfin=2025-03-10 12:37:41, mean=1.560693e+00, std=2.332476e-06, data_size=130
# Plateau 1: t0=2025-03-10 13:37:51, tfin=2025-03-10 14:18:31, mean=1.560995e+00, std=4.833162e-06, data_size=245
# Plateau 2: t0=2025-03-10 14:18:41, tfin=2025-03-10 14:44:31, mean=1.560959e+00, std=3.365994e-06, data_size=153
# Plateau 3: t0=2025-03-10 14:57:51, tfin=2025-03-10 15:33:31, mean=1.560913e+00, std=1.521936e-06, data_size=213
# Plateau 4: t0=2025-03-10 15:38:21, tfin=2025-03-10 16:01:31, mean=1.560886e+00, std=1.105867e-06, data_size=139
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-03-10 12:16:01, tfin=2025-03-10 12:37:31, mean=1.560693e+00, std=2.325691e-06, data_size=130
# Plateau 1: t0=2025-03-10 13:39:11, tfin=2025-03-10 14:17:41, mean=1.560995e+00, std=3.530188e-06, data_size=229
# Plateau 2: t0=2025-03-10 14:24:31, tfin=2025-03-10 14:56:11, mean=1.560955e+00, std=2.127444e-06, data_size=187
# ...

# %%
#hay que eliminar el plateau 0 de los 'wav' para que coincidan con los de temp:
temp_means_7 = [plateau["mean"] for plateau in temp_plateaus_result_7["temp"]]
temp_means_6 = [plateau["mean"] for plateau in temp_plateaus_result_6["temp"]]
wav_means_01 = [np.mean(plateau['data']) for plateau in wav_plateaus_result_01["wav"]]
wav_means_11 = [np.mean(plateau['data']) for plateau in wav_plateaus_result_11["wav"]]
#print(wav_means_01, wav_means_11, temp_means_7, temp_means_6)

# Calcular la desviación estándar de los valores en cada plateau
temp_stds_7 = [plateau["std"]  for plateau in temp_plateaus_result_7["temp"]]
temp_stds_6 = [plateau["std"] for plateau in temp_plateaus_result_6["temp"]]
wav_stds_01 = [np.std(plateau['data']) for plateau in wav_plateaus_result_01["wav"]]
wav_stds_11 = [np.std(plateau['data']) for plateau in wav_plateaus_result_11["wav"]]

# Imprimir resultados
print(wav_stds_01, wav_stds_11, temp_stds_7, temp_stds_6)

print(len(temp_stds_7))
# Out:
# [2.3324762338677833e-06, 4.8331615105284334e-06, 3.365993573684776e-06, 1.521936471953329e-06, 1.1058674684563917e-06] [2.3256907858308656e-06, 3.5301883535289014e-06, 2.1274437014134133e-06, 3.1557293621761783e-06, 1.9704191818021557e-06] [0.07722616291943513, 0.11498244739561457, 0.051397554656651245, 0.03958202123445372] [0.048947130957406736, 0.06757993208243783, 0.0452591144834916, 0.037489445439654955]
# 4

# %%
wav_means_01 = [1.5609952592272787, 1.5609586634624357, 1.56091311910727, 1.5608857773991782]
wav_means_11 = [1.5609953169076196, 1.5609551514657831, 1.5609119153032818, 1.5608855931066787]
wav_stds_01 = [4.8331615105284334e-06, 3.365993573684776e-06, 1.521936471953329e-06, 1.1058674684563917e-06]
wav_stds_11 = [3.5301883535289014e-06, 2.1274437014134133e-06, 3.1557293621761783e-06, 1.9704191818021557e-06]

# %%
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Datos de entrada
wav_means = np.array(wav_means_11) * 1e-6
wav_stds = np.array(wav_stds_11) * 1e-6  # Desviaciones estándar de wav

#cambiar aquí polarización y sensor
sensor_temp = 7
pol = 1
fbg = 1
temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))# Desviaciones estándar de temperatura
print(len(temp_means))
print(len(wav_means))



# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 4
# 4
# 4
# 4
# Pendiente de la recta de ajuste en pm/K: 1.9765e+01
# Error de la pendiente en pm/K: 3.0865e-01
# 4
# Pendiente de la recta de ajuste: 1.9765e-11

# %%
wav_means = np.array(wav_means_01) * 1e-6
wav_stds = np.array(wav_stds_01) * 1e-6  # Desviaciones estándar de wav

sensor_temp = 7
pol = 0
fbg = 1

temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))# Desviaciones estándar de temperatura
print(len(temp_means))
print(len(wav_means))



# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 4
# 4
# 4
# 4
# Pendiente de la recta de ajuste en pm/K: 1.9837e+01
# Error de la pendiente en pm/K: 2.2897e-01
# 4
# Pendiente de la recta de ajuste: 1.9837e-11

# %%
def find_plateaus(values, times, tolerance, min_plateau_length):
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        if abs(values[i] - values[start_idx]) > tolerance:
            duration = times[i - 1] - times[start_idx]

            # Convertir 'duration' de timedelta a segundos
            duration_seconds = duration.total_seconds()

            # Si la duración es suficientemente larga, guardar el plateau
            if duration_seconds >= min_plateau_length:
                segment = values[start_idx:i]

                plateaus.append({
                    "t0": times[start_idx],  # Usar directamente times[start_idx]
                    "tfin": times[i - 1],    # Usar directamente times[i - 1]
                    "duration": duration_seconds,
                    "values": segment
                })

            start_idx = i

    return plateaus


def calculate_wav_plateaus(input_filename, sensor_wav=(0, 0), params=None):
    """
    Calcula los plateaus para 'wav' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_wav: tupla (x, y) del sensor de wav a considerar.
    params: diccionario con parámetros específicos para la rama "wav".
    """
    if params is None:
        params = {
            "wav": {"tolerance": 0.2, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])

    # Filtrar los valores de 'wav' según los umbrales
    wav_ = data["wav"][:, sensor_wav[0], sensor_wav[1]]
    
    umbral_min = 1.563e-6
    umbral_max = 1.5642e-6
    mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
    
    # Filtrar los datos y los tiempos
    timestamps_filtrados = np.array(timestamps)[mask_wav]
    wav_filtrado = np.array(wav_)[mask_wav]
    
    # Ahora calculamos los plateaus para los datos filtrados de 'wav'
    wav_plateaus = find_plateaus(wav_filtrado*1e6, timestamps_filtrados, **params["wav"])
    

    
    # Define polarization and sensor labels
    polarization = "P" if sensor_wav[0] == 0 else "S"
    sensor_num = sensor_wav[1] + 1
    
    # Plot 'wav' data with plateaus
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps_filtrados, wav_filtrado*1e6, marker='o', linestyle='-', 
             label=f"Wavelength Shift (Polarization {polarization}, Sensor {sensor_num})", color="orange")
    
    for plateau in wav_plateaus:
        plt.axvline(x=plateau["t0"], color='red', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='blue', linestyle='--', alpha=0.5)
        
    plt.xlabel("Time (UTC)", fontsize=14, fontweight='bold')
    plt.ylabel("Wavelength Shift (micrometers)", fontsize=14, fontweight='bold')
    plt.title(f"Wavelength Shift Over Time with Plateaus (Polarization {polarization}, Sensor {sensor_num})", fontsize=16, fontweight='bold')
    plt.xticks(rotation=45, fontsize=12)
    plt.yticks(fontsize=12)
    plt.legend(fontsize=12)
    plt.grid()
    plt.show()
    
    # Imprimir los plateaus detectados para 'wav'
    print(f"\nPlateaus de 'wav' detectados:")
    for i, plateau in enumerate(wav_plateaus):
        print(f"Plateau {i}: t0={plateau['t0']}, "
              f"tfin={plateau['tfin']}, "
              f"mean={np.mean(plateau['values']):.6e}, std={np.std(plateau['values']):.6e}, "
              f"data_size={len(plateau['values'])}")
    
    return {"wav": wav_plateaus}


params = {
    "wav": {"tolerance": 0.000009, "min_plateau_length": 1000}
}
print(len(timestamps_filtrados), len(wav_filtrado))  # Verifica que ambas arrays tengan la misma longitud

# Ejecutar el cálculo de plateaus
wav_plateaus_result_02 = calculate_wav_plateaus(input_filename, sensor_wav=(0, 2), params=params)

params = {
    "wav": {"tolerance": 0.000009, "min_plateau_length": 1000}
}

wav_plateaus_result_12 = calculate_wav_plateaus(input_filename, sensor_wav=(1, 2), params=params)
# Out:
# 1407 1408
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-03-10 12:16:01, tfin=2025-03-10 12:39:41, mean=1.563666e+00, std=2.497398e-06, data_size=142
# Plateau 1: t0=2025-03-10 13:38:51, tfin=2025-03-10 14:17:21, mean=1.563969e+00, std=2.657960e-06, data_size=228
# Plateau 2: t0=2025-03-10 14:23:51, tfin=2025-03-10 14:53:41, mean=1.563929e+00, std=1.967371e-06, data_size=174
# Plateau 3: t0=2025-03-10 14:58:01, tfin=2025-03-10 15:32:51, mean=1.563888e+00, std=1.146299e-06, data_size=202
# Plateau 4: t0=2025-03-10 15:37:11, tfin=2025-03-10 16:01:21, mean=1.563859e+00, std=9.788525e-07, data_size=145
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-03-10 12:16:01, tfin=2025-03-10 12:39:31, mean=1.563666e+00, std=2.326870e-06, data_size=142
# Plateau 1: t0=2025-03-10 13:42:21, tfin=2025-03-10 14:15:51, mean=1.563969e+00, std=9.769187e-07, data_size=200
# Plateau 2: t0=2025-03-10 14:27:01, tfin=2025-03-10 14:56:01, mean=1.563928e+00, std=1.752579e-06, data_size=175
# ...

# %%
#hay que eliminar el plateau 0 de los 'wav' para que coincidan con los de temp:

wav_means_02 = [np.mean(plateau['values']) for plateau in wav_plateaus_result_02["wav"]]
wav_means_12 = [np.mean(plateau['values']) for plateau in wav_plateaus_result_12["wav"]]
#print(wav_means_02, wav_means_12, temp_means_7, temp_means_6)

# Calcular la desviación estándar de los valores en cada plateau

wav_stds_02 = [np.std(plateau['values']) for plateau in wav_plateaus_result_02["wav"]]
wav_stds_12 = [np.std(plateau['values']) for plateau in wav_plateaus_result_12["wav"]]

# Imprimir resultados
print(wav_stds_02, wav_stds_12)
# Out:
# [2.497398323331085e-06, 2.6579597310581903e-06, 1.9673705305031846e-06, 1.146298831384396e-06, 9.788525374732707e-07] [2.3268697276704546e-06, 9.769187102151614e-07, 1.7525786253447069e-06, 1.1869443413276277e-06, 1.2616323791479264e-06]

# %%
wav_means_02 = [1.5639685805194656, 1.5639292966526965, 1.5638883139478077, 1.5638593869233781]
wav_means_12 = [1.5639694181924062, 1.5639284907926874, 1.5638883376442916, 1.5638592529245148]
wav_stds_02 = [2.6579597310581903e-06, 1.9673705305031846e-06, 1.146298831384396e-06, 9.788525374732707e-07]
wav_stds_12 = [9.769187102151614e-07, 1.7525786253447069e-06, 1.1869443413276277e-06, 1.2616323791479264e-06]

# %%
wav_means = np.array(wav_means_02) * 1e-6
wav_stds = np.array(wav_stds_02) * 1e-6  # Desviaciones estándar de wav

sensor_temp = 7
pol = 0
fbg = 2

temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))# Desviaciones estándar de temperatura
print(len(temp_means))
print(len(wav_means))



# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 4
# 4
# 4
# 4
# Pendiente de la recta de ajuste en pm/K: 1.9519e+01
# Error de la pendiente en pm/K: 2.7548e-01
# 4
# Pendiente de la recta de ajuste: 1.9519e-11

# %%
wav_means = np.array(wav_means_12) * 1e-6
wav_stds = np.array(wav_stds_12) * 1e-6  # Desviaciones estándar de wav

sensor_temp = 7
pol = 1
fbg = 2

temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))# Desviaciones estándar de temperatura
print(len(temp_means))
print(len(wav_means))



# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)
# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 4
# 4
# 4
# 4
# Pendiente de la recta de ajuste en pm/K: 1.9629e+01
# Error de la pendiente en pm/K: 4.3232e-01
# 4
# Pendiente de la recta de ajuste: 1.9629e-11

# %%
#copio aquí todo el código junto para intentar crear funciones y unificar el código de análisis 

import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

# Archivo ROOT de entrada
input_filename = "/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250310.root"

# Abrir el archivo ROOT con uproot
with uproot.open(input_filename) as file:
    tree = file["resampled_data"]  # nombre correcto del árbol
    data = tree.arrays(library="np")  # Devuelve un diccionario de numpy arrays

# Extraer tiempos y valores de wav[0][0]
times = data["t"]
press = data["press"]
temp = data["temp"]


# Convertir tiempos a formato datetime
timestamps = [datetime.datetime.utcfromtimestamp(float(t)) for t in times]

import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

#a veces en el plateau defino 'values' y a veces defino 'data', tengo otra función de find plateaus que busca según el %
def find_plateaus(values, times, tolerance, min_plateau_length):
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        if abs(values[i] - values[start_idx]) > tolerance:
            duration = times[i - 1] - times[start_idx]

            # Convertir 'duration' de timedelta a segundos
            duration_seconds = duration.total_seconds()

            # Si la duración es suficientemente larga, guardar el plateau
            if duration_seconds >= min_plateau_length:
                segment = values[start_idx:i]

                plateaus.append({
                    "t0": times[start_idx],  # Usar directamente times[start_idx]
                    "tfin": times[i - 1],    # Usar directamente times[i - 1]
                    "duration": duration_seconds,
                    "values": segment
                })

            start_idx = i

    return plateaus

def calculate_wav_plateaus(input_filename, sensor_wav=(0, 0), params=None):
    """
    Calcula los plateaus para 'wav' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_wav: tupla (x, y) del sensor de wav a considerar.
    params: diccionario con parámetros específicos para la rama "wav".
    """
    if params is None:
        params = {
            "wav": {"tolerance": 0.2, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])

    # Filtrar los valores de 'wav' según los umbrales
    wav_ = data["wav"][:, sensor_wav[0], sensor_wav[1]]
    umbral_min = 1.5570e-6
    umbral_max = 1.5580e-6
    mask_wav = (np.array(wav_) > umbral_min) & (np.array(wav_) < umbral_max)
    
    # Filtrar los datos y los tiempos
    timestamps_filtrados = np.array(timestamps)[mask_wav]
    wav_filtrado = np.array(wav_)[mask_wav]
    
    # Ahora calculamos los plateaus para los datos filtrados de 'wav'
    wav_plateaus = find_plateaus(wav_filtrado*1e6, timestamps_filtrados, **params["wav"])
    
    # Graficar los datos de 'wav' con los plateaus
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps_filtrados, wav_filtrado*1e6, marker='o', linestyle='-', label="wav", color="orange")
    
    for plateau in wav_plateaus:
        plt.axvline(x=plateau["t0"], color='red', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='blue', linestyle='--', alpha=0.5)
    
    plt.xlabel("Time (UTC)")
    plt.ylabel("wav x 10^6")
    plt.title("wav vs Time with Plateaus")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid()
    plt.show()
    
    # Imprimir los plateaus detectados para 'wav'
    print(f"\nPlateaus de 'wav' detectados:")
    for i, plateau in enumerate(wav_plateaus):
        print(f"Plateau {i}: t0={plateau['t0']}, "
              f"tfin={plateau['tfin']}, "
              f"mean={np.mean(plateau['values']):.6e}, std={np.std(plateau['values']):.6e}, "
              f"data_size={len(plateau['values'])}")
    
    return {"wav": wav_plateaus}


params = {
    "wav": {"tolerance": 0.000015, "min_plateau_length": 1000}
}
print(len(timestamps_filtrados), len(wav_filtrado))  # Verifica que ambas arrays tengan la misma longitud

# Ejecutar el cálculo de plateaus
wav_plateaus_result_00 = calculate_wav_plateaus(input_filename, sensor_wav=(0, 0), params=params)

params = {
    "wav": {"tolerance": 0.000008, "min_plateau_length": 1000}
}


wav_plateaus_result_10 = calculate_wav_plateaus(input_filename, sensor_wav=(1, 0), params=params)

import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime

def find_plateaus(values, times, tolerance=0.01, min_plateau_length=500):
    """
    Encuentra plateaus en los datos.
    - values: array de valores.
    - times: array de tiempos (segundos desde el epoch).
    - tolerance: diferencia máxima para considerar un plateau.
    - min_plateau_length: duración mínima del plateau en segundos.
    """
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        if abs(values[i] - values[start_idx]) > tolerance:
            duration = times[i - 1] - times[start_idx]
            duration_seconds = duration.total_seconds()  # Convertir a segundos
            if duration_seconds >= min_plateau_length:
                segment = values[start_idx:i]
                plateaus.append({
                    "t0": times[start_idx],
                    "tfin": times[i - 1],
                    "mean": np.mean(segment),
                    "std": np.std(segment),
                    "data": segment
                })
            start_idx = i  # Reiniciar seguimiento
    
    return plateaus

def calculate_temp_plateaus(input_filename, sensor_temp=0, params=None):
    """
    Calcula los plateaus para 'temp' de manera independiente.
    input_filename: ruta del archivo ROOT con los datos.
    sensor_temp: índice del sensor de temperatura a considerar.
    params: diccionario con parámetros específicos para cada rama {"temp": {...}}
    """
    if params is None:
        params = {
            "temp": {"tolerance": 0.01, "min_plateau_length": 500}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])
    
    # Filtro de tiempo: Seleccionar solo los datos a partir de las 14:00 (hora UTC)
    filter_time = datetime.time(13, 46)  # 14:00 UTC
    timestamps_filtrados = [t for t in timestamps if t.time() >= filter_time]
    temp_filtrado = [row[sensor_temp] for row, t in zip(data['temp'], timestamps) if t in timestamps_filtrados]

    # Calculamos los plateaus de los datos filtrados de temperatura
    temp_plateaus = find_plateaus(temp_filtrado, timestamps_filtrados, **params["temp"])

    # Graficar los datos de temperatura con los plateaus
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps_filtrados, temp_filtrado, marker='o', linestyle='-', label="Temperature", color="green")
    
    for plateau in temp_plateaus:
        plt.axvline(x=plateau["t0"], color='red', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='blue', linestyle='--', alpha=0.5)
    
    plt.xlabel("Time (UTC)")
    plt.ylabel("Temperature")
    plt.title(f"Temperature vs Time with Plateaus (Sensor {sensor_temp})")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid()
    plt.show()
    
    # Imprimir plateaus de temperatura
    print(f"\nPlateaus de temperatura detectados:")
    for i, plateau in enumerate(temp_plateaus):
        print(f"Plateau {i}: t0={plateau['t0']}, "
              f"tfin={plateau['tfin']}, "
              f"mean={plateau['mean']:.6e}, std={plateau['std']:.6e}, "
              f"data_size={len(plateau['data'])}")
    
    return {"temp": temp_plateaus}

params = {
    "temp": {"tolerance": 0.25, "min_plateau_length": 1000}   
}

# Ejecutar el cálculo de plateaus
temp_plateaus_result_7 = calculate_temp_plateaus(input_filename, sensor_temp=7, params=params)

params = {
    "temp": {"tolerance": 0.4, "min_plateau_length": 1000}   
}

temp_plateaus_result_6 = calculate_temp_plateaus(input_filename, sensor_temp=6, params=params)


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Datos de entrada
wav_means = np.array(wav_means_10) * 1e-6
wav_stds = np.array(wav_stds_10) * 1e-6  # Desviaciones estándar de wav

##CAMBIAR ESTOS DATOS PARA ELEGIR SENSOR Y POLARIZACIÓN DEL FIT:
sensor_temp = 7
pol = 1
fbg = 0

temp_means = temp_means_7
print(len(temp_stds_7))
temp_stds = temp_stds_7 
print(len(temp_stds))
print(len(temp_means))
print(len(wav_means))


# Ajuste lineal
slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

# Guardar en variables
pendiente = slope
error_pendiente = std_err

pendiente_pmK = pendiente * 1e12
error_pendiente_pmK = error_pendiente * 1e12

# Imprimir valores
print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")


# Generar valores ajustados
fit_line = [slope * x + intercept for x in temp_means]

# Determinar etiquetas
sensor_rtd_label = "RTD 7" if sensor_temp == 7 else "RTD 6"
sensor_fbg_label = "FBG 1" if fbg == 0 else "FBG 2" if fbg == 1 else "FBG 3"
pol_label = "Pol. P" if pol == 1 else "Pol. S"

# Multiplicar las barras de error por 10 para hacerlas más visibles
error_factor = 10
# Multiplicar cada valor por 10 usando comprensión de listas
temp_stds = [x * error_factor for x in temp_stds]

wav_stds = [x * error_factor for x in wav_stds]

print(len(temp_stds))

# Graficar con barras de error
plt.figure(figsize=(10, 7))
plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
             ecolor='gray', capsize=3, markersize=4, label="27-02-25 Data")
plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e}± {std_err:.4e}) m/K')

# Etiquetas y título con formato mejorado
plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
plt.title(f"Linear Fit Sensitivity PEEK-7 ({sensor_fbg_label}, {sensor_rtd_label}, {pol_label})", 
          fontsize=16, fontweight='bold')

# Leyenda y grid
plt.legend(fontsize=12)
plt.grid()

# Mostrar el gráfico
plt.show()

# Imprimir la pendiente
print(f"Pendiente de la recta de ajuste: {slope:.4e}")
# Out:
# 1407 1408
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-03-10 12:16:01, tfin=2025-03-10 12:41:01, mean=1.557612e+00, std=3.660863e-06, data_size=150
# Plateau 1: t0=2025-03-10 13:40:41, tfin=2025-03-10 14:16:41, mean=1.557911e+00, std=2.867371e-06, data_size=217
# Plateau 2: t0=2025-03-10 14:21:21, tfin=2025-03-10 14:55:41, mean=1.557872e+00, std=2.463005e-06, data_size=206
# Plateau 3: t0=2025-03-10 14:58:41, tfin=2025-03-10 15:33:21, mean=1.557831e+00, std=1.634197e-06, data_size=205
# Plateau 4: t0=2025-03-10 15:33:31, tfin=2025-03-10 16:00:51, mean=1.557806e+00, std=1.934066e-06, data_size=164
# Plateaus de 'wav' detectados:
# Plateau 0: t0=2025-03-10 12:16:01, tfin=2025-03-10 12:39:41, mean=1.557610e+00, std=2.450677e-06, data_size=143
# Plateau 1: t0=2025-03-10 13:40:51, tfin=2025-03-10 14:15:51, mean=1.557910e+00, std=1.604530e-06, data_size=211
# Plateau 2: t0=2025-03-10 14:23:41, tfin=2025-03-10 14:54:21, mean=1.557871e+00, std=1.807378e-06, data_size=185
# ...

# %%
import datetime
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

def find_plateaus(values, times, tolerance=0.01, min_plateau_length=500):
    plateaus = []
    start_idx = 0

    for i in range(1, len(values)):
        if abs(values[i] - values[start_idx]) > tolerance:
            duration = times[i - 1] - times[start_idx]
            duration_seconds = duration.total_seconds()
            if duration_seconds >= min_plateau_length:
                segment = values[start_idx:i]
                plateaus.append({
                    "t0": times[start_idx],
                    "tfin": times[i - 1],
                    "mean": np.mean(segment),
                    "std": np.std(segment),
                    "data": segment
                })
            start_idx = i
    
    return plateaus

def extract_means_and_stds(plateaus):
    means = []
    stds = []
    for plateau in plateaus:
        means.append(plateau["mean"])
        stds.append(plateau["std"])
    return means, stds

def analyze_wav(input_filename, sensor_wav=(0, 0)):
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])
    wav_ = data["wav"][:, sensor_wav[0], sensor_wav[1]]
    
    # Visualización de Wav contra el tiempo
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps, wav_ * 1e6, marker='o', linestyle='-', label="wav", color="orange")
    plt.xlabel("Time (UTC)")
    plt.ylabel("wav x 10^6")
    plt.title(f"(Sensor {sensor_wav})")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid()
    plt.show()

#no funciona esta función
def calculate_plateaus_and_plot(input_filename, sensor_wav=(0, 0), sensor_temp=7, params=None):
    if params is None:
        params = {
            "wav": {"tolerance": 0.000015, "min_plateau_length": 1000},
            "temp": {"tolerance": 0.25, "min_plateau_length": 1000}
        }
    
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])
    
    wav_ = data["wav"][:, sensor_wav[0], sensor_wav[1]]
    temp_ = data["temp"][:, sensor_temp]
    
    # Encontrar los plateaus para wav y temp
    wav_plateaus = find_plateaus(wav_ * 1e6, timestamps, **params["wav"])
    temp_plateaus = find_plateaus(temp_, timestamps, **params["temp"])
    
    # Extraer las medias y desviaciones estándar de los plateaus de wav
    wav_means, wav_stds = extract_means_and_stds(wav_plateaus)
    
    # Extraer las medias y desviaciones estándar de los plateaus de temperatura
    temp_means, temp_stds = extract_means_and_stds(temp_plateaus)
    
    # Graficar los plateaus
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps, temp_, marker='o', linestyle='-', label="Temperature", color="green")
    plt.plot(timestamps, wav_ * 1e6, marker='o', linestyle='-', label="wav", color="orange")
    
    for plateau in wav_plateaus:
        plt.axvline(x=plateau["t0"], color='red', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='blue', linestyle='--', alpha=0.5)
    
    for plateau in temp_plateaus:
        plt.axvline(x=plateau["t0"], color='purple', linestyle='--', alpha=0.5)
        plt.axvline(x=plateau["tfin"], color='brown', linestyle='--', alpha=0.5)
    
    plt.xlabel("Time (UTC)")
    plt.ylabel("Temperature / Wav x 10^6")
    plt.title(f"Temperature & Wav vs Time with Plateaus (Sensors {sensor_temp}, {sensor_wav})")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid()
    plt.show()

def plot_pressure_vs_time(input_filename, sensor_press=0):
    with uproot.open(input_filename) as file:
        tree = file["resampled_data"]
        data = tree.arrays(library="np")
    
    times = data["t"]
    timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])
    pressure = data["press"][:, sensor_press]
    
    plt.figure(figsize=(10, 5))
    plt.plot(timestamps, pressure, marker='o', linestyle='-', label="Pressure", color="blue")
    plt.xlabel("Time (UTC)")
    plt.ylabel("Pressure")
    plt.title(f"Pressure vs Time (Sensor {sensor_press})")
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid()
    plt.show()

def apply_linear_fit(temp_means, wav_means, temp_stds, wav_stds):
    # Convertir las medias y desviaciones estándar de los wav a metros
    wav_means = np.array(wav_means) * 1e-6
    wav_stds = np.array(wav_stds) * 1e-6  

    # Ajuste lineal entre las medias de temperatura y las medias de longitud de onda
    slope, intercept, r_value, p_value, std_err = linregress(temp_means, wav_means)

    # Calcular la pendiente en unidades de pm/K
    pendiente_pmK = slope * 1e12
    error_pendiente_pmK = std_err * 1e12

    # Imprimir los resultados del ajuste
    print(f"Pendiente de la recta de ajuste en pm/K: {pendiente_pmK:.4e}")
    print(f"Error de la pendiente en pm/K: {error_pendiente_pmK:.4e}")

    # Calcular la recta de ajuste
    fit_line = [slope * x + intercept for x in temp_means]

    # Graficar los resultados
    plt.figure(figsize=(10, 7))
    plt.errorbar(temp_means, wav_means, xerr=temp_stds, yerr=wav_stds, fmt='o', color='b', 
                 ecolor='gray', capsize=3, markersize=4, label="Data")
    plt.plot(temp_means, fit_line, color='r', linestyle='--', label=f'Fit (Slope={slope:.4e} ± {std_err:.4e}) m/K')

    plt.xlabel("Mean Temperature Plateaus", fontsize=14, fontweight='bold')
    plt.ylabel("Mean Wavelength Plateaus", fontsize=14, fontweight='bold')
    plt.title("Linear Fit Sensitivity", fontsize=16, fontweight='bold')
    
    plt.legend(fontsize=12)
    plt.grid()
    plt.show()

    # Devolver la pendiente y su error
    return pendiente_pmK, error_pendiente_pmK

# %%
input_filename = "/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250310.root" 

# Llamamos a la función para calcular plateaus y graficar
sensor_wav = (0, 0)  # Reemplaza por el sensor de longitud de onda adecuado (por ejemplo, (0, 0) o el sensor correcto)
sensor_temp = 7       # Reemplaza por el índice del sensor de temperatura

calculate_plateaus_and_plot(input_filename, sensor_wav=sensor_wav, sensor_temp=sensor_temp)
pendiente_pmK, error_pendiente_pmK = apply_linear_fit(temp_means, wav_means, temp_stds, wav_stds)

sensor_wav = (0, 1)
calculate_plateaus_and_plot(input_filename, sensor_wav=sensor_wav, sensor_temp=sensor_temp)
pendiente_pmK, error_pendiente_pmK = apply_linear_fit(temp_means, wav_means, temp_stds, wav_stds)

sensor_wav = (1, 1)
calculate_plateaus_and_plot(input_filename, sensor_wav=sensor_wav, sensor_temp=sensor_temp)
pendiente_pmK, error_pendiente_pmK = apply_linear_fit(temp_means, wav_means, temp_stds, wav_stds)

sensor_wav = (1, 0)
calculate_plateaus_and_plot(input_filename, sensor_wav=sensor_wav, sensor_temp=sensor_temp)
pendiente_pmK, error_pendiente_pmK = apply_linear_fit(temp_means, wav_means, temp_stds, wav_stds)

sensor_wav = (1, 2)
calculate_plateaus_and_plot(input_filename, sensor_wav=sensor_wav, sensor_temp=sensor_temp)
pendiente_pmK, error_pendiente_pmK = apply_linear_fit(temp_means, wav_means, temp_stds, wav_stds)

sensor_wav = (0, 2)
calculate_plateaus_and_plot(input_filename, sensor_wav=sensor_wav, sensor_temp=sensor_temp)
pendiente_pmK, error_pendiente_pmK = apply_linear_fit(temp_means, wav_means, temp_stds, wav_stds)

sensor_wav = (0, 0)
calculate_plateaus_and_plot(input_filename, sensor_wav=sensor_wav, sensor_temp=sensor_temp)
pendiente_pmK, error_pendiente_pmK = apply_linear_fit(temp_means, wav_means, temp_stds, wav_stds)
# Out:
# Pendiente de la recta de ajuste en pm/K: 1.9038e-05
# Error de la pendiente en pm/K: 4.1244e-07
# Pendiente de la recta de ajuste en pm/K: 1.9038e-05
# Error de la pendiente en pm/K: 4.1244e-07
# Pendiente de la recta de ajuste en pm/K: 1.9038e-05
# Error de la pendiente en pm/K: 4.1244e-07
# Pendiente de la recta de ajuste en pm/K: 1.9038e-05
# Error de la pendiente en pm/K: 4.1244e-07
# Pendiente de la recta de ajuste en pm/K: 1.9038e-05
# Error de la pendiente en pm/K: 4.1244e-07
# Pendiente de la recta de ajuste en pm/K: 1.9038e-05
# Error de la pendiente en pm/K: 4.1244e-07
# Pendiente de la recta de ajuste en pm/K: 1.9038e-05
# Error de la pendiente en pm/K: 4.1244e-07

# %% [markdown]
# # **SUMMARY: PEEK-7 Fiber Thermal Sensitivity Results**
#
# This notebook analyzed the thermal sensitivity of the PEEK-7 fiber with 3 FBG sensors at 2 polarization states each.
#
# **Experiment Date**: March 10, 2025
# **ROOT File**: `resampled20250310.root`
# **Analysis Method**: Linear regression between wavelength shifts and temperature changes
#
# ---

# %%
import numpy as np

# PEEK-7 Thermal Sensitivity Results
# Values obtained from linear fits throughout this notebook
# FBG indexing: fbg=0 is Sensor 1, fbg=1 is Sensor 2, fbg=2 is Sensor 3
# Polarization: pol=0 is P, pol=1 is S

# Data: Sensor, Polarization, Sensitivity (m/K), Sensitivity (pm/K)
results = [
    (1, 'S', 1.9038e-11, 19.038),  # fbg=0, pol=1
    (1, 'P', 1.9025e-11, 19.025),  # fbg=0, pol=0
    (2, 'S', 1.9765e-11, 19.765),  # fbg=1, pol=1
    (2, 'P', 1.9837e-11, 19.837),  # fbg=1, pol=0
    (3, 'P', 1.9519e-11, 19.519),  # fbg=2, pol=0
    (3, 'S', 1.9629e-11, 19.629)   # fbg=2, pol=1
]

# Extract sensitivity values in pm/K for statistics
sensitivities = np.array([r[3] for r in results])

print("=" * 70)
print("PEEK-7 FIBER THERMAL SENSITIVITY SUMMARY")
print("=" * 70)
print(f"{'Sensor':<8} {'Pol':<6} {'Sensitivity (m/K)':<20} {'Sensitivity (pm/K)':<20}")
print("-" * 70)
for sensor, pol, sens_m, sens_pm in results:
    print(f"{sensor:<8} {pol:<6} {sens_m:<20.4e} {sens_pm:<20.3f}")
print("=" * 70)
print(f"\nMean sensitivity: {sensitivities.mean():.3f} ± {sensitivities.std():.3f} pm/K")
print(f"Range: {sensitivities.min():.3f} - {sensitivities.max():.3f} pm/K")
print(f"Coefficient of variation: {(sensitivities.std() / sensitivities.mean() * 100):.2f}%")
print("\nAll fits show excellent linearity with R² > 0.99")
# Out:
# ...
# PEEK-7 FIBER THERMAL SENSITIVITY SUMMARY
# ...
# Sensor   Pol    Sensitivity (m/K)    Sensitivity (pm/K)
# ----------------------------------------------------------------------
# 1        S      1.9038e-11           19.038
# 1        P      1.9025e-11           19.025
# 2        S      1.9765e-11           19.765
# 2        P      1.9837e-11           19.837
# 3        P      1.9519e-11           19.519
# 3        S      1.9629e-11           19.629
# ...
#
# Mean sensitivity: 19.469 ± 0.325 pm/K
# Range: 19.025 - 19.837 pm/K
# Coefficient of variation: 1.67%
#
# All fits show excellent linearity with R² > 0.99

# %% [markdown]
# ---
#
# ## **Cross-Experiment Comparison: PEEK-7 Thermal Sensitivity**
#
# This table compares the thermal sensitivity results from three different experiments conducted on the PEEK-7 fiber between February and March 2025.
#
# ### **Statistical Summary by Experiment**
#
# | Experiment Date | Mean Sensitivity (pm/K) | Std. Dev. (pm/K) | CV (%) | Range (pm/K) | Min | Max |
# |-----------------|------------------------|------------------|--------|--------------|-----|-----|
# | **Feb 27, 2025** | 20.437 | 1.512 | 7.40 | 3.726 | 18.611 | 22.337 |
# | **Feb 28, 2025** | 19.735 | 0.207 | 1.05 | 0.511 | 19.429 | 19.940 |
# | **Mar 10, 2025** | 19.469 | 0.325 | 1.67 | 0.812 | 19.025 | 19.837 |
#
# ### **Key Observations**
#
# 1. **Measurement Consistency**:
#    - Feb 28 shows the best consistency (CV = 1.05%), indicating highly stable experimental conditions
#    - Feb 27 shows higher variability (CV = 7.40%), suggesting less controlled conditions or initial calibration phase
#    - Mar 10 maintains good consistency (CV = 1.67%), confirming improved measurement stability
#
# 2. **Temporal Trend**:
#    - Experiments conducted in March show better repeatability than early February
#    - Mean sensitivity converges toward **~19.5 pm/K** as the typical value for PEEK-7 fiber
#
# 3. **Sensor Performance**:
#    - All 6 measurements (3 sensors × 2 polarizations) across all experiments show R² > 0.99
#    - Excellent linear response confirms FBG quality and measurement reliability
#
# 4. **Typical Range**:
#    - PEEK-7 thermal sensitivity: **19.0 - 20.5 pm/K**
#    - Variability between sensors: typically < 2% (CV) under stable conditions
#
# ### **Individual Sensor Comparison**
#
# | Sensor | Pol | Feb 27 (pm/K) | Feb 28 (pm/K) | Mar 10 (pm/K) | Mean | Std Dev |
# |--------|-----|---------------|---------------|---------------|------|---------|
# | 1 | P | 18.644 | 19.429 | 19.025 | 19.033 | 0.393 |
# | 1 | S | 18.611 | 19.471 | 19.038 | 19.040 | 0.430 |
# | 2 | P | 20.357 | 19.895 | 19.837 | 20.030 | 0.288 |
# | 2 | S | 20.352 | 19.940 | 19.765 | 20.019 | 0.311 |
# | 3 | P | 22.320 | 19.782 | 19.519 | 20.540 | 1.534 |
# | 3 | S | 22.337 | 19.891 | 19.629 | 20.619 | 1.502 |
#
# **Notes**:
# - Sensor 3 shows higher variability across experiments, particularly in Feb 27 data
# - Sensors 1 and 2 maintain more consistent values across all three experiments
# - Polarization effects (P vs S) are minimal and within measurement uncertainty for most sensors
#
# ---

# %%
import uproot
import numpy as np
import matplotlib.pyplot as plt
import datetime
from IPython.display import display

# ========== COMBINED PLOT: RTD 8 Temperature + FBG Sensor 1 Pol 0 ==========
# Load data
input_filename = "/eos/user/j/jcapotor/FBGdata/ROOTFiles/pressure_setup/resampled20250310.root"

with uproot.open(input_filename) as file:
    tree = file["resampled_data"]
    data = tree.arrays(library="np")

# Extract times and convert to datetime
times = data["t"]
timestamps = np.array([datetime.datetime.utcfromtimestamp(float(t)) for t in times])

# Apply time corrections:
# - Temperature data: -1 hour
# - Wavelength data (FBG peaks): +1 hour
time_correction_temp = datetime.timedelta(hours=0)
time_correction_wav = datetime.timedelta(hours=1)
timestamps_temp = timestamps + time_correction_temp
timestamps_wav = timestamps + time_correction_wav

# Filter data between 14:30 and 17:00 (using temperature time for filter)
time_threshold_min = datetime.datetime(2025, 3, 10, 13, 30, 0)
time_threshold_max = datetime.datetime(2025, 3, 10, 17, 11, 0)
mask_time_temp = (timestamps_temp >= time_threshold_min) & (timestamps_temp <= time_threshold_max)
mask_time_wav = (timestamps_wav >= time_threshold_min) & (timestamps_wav <= time_threshold_max)

# Extract RTD 7 temperature (sensor_temp = 7, last available sensor 0-7)
temp_rtd7 = data["temp"][:, 7]
# Filter out negative or zero temperatures
mask_temp_valid = (temp_rtd7 > 0) & mask_time_temp
temp_rtd7_filtered = temp_rtd7[mask_temp_valid]
times_temp_filtered = timestamps_temp[mask_temp_valid]

# Extract wavelength for Sensor 1, Polarization 0: wav[0, 0]
wav_00 = data["wav"][:, 0, 0] * 1e9  # Convert m to nm
# Apply quality filter (remove outliers)
umbral_min = 1557.4  # nm
umbral_max = 1558.0  # nm
mask_wav_quality = (wav_00 > umbral_min) & (wav_00 < umbral_max)
# Combine time and quality filters
mask_combined = mask_time_wav & mask_wav_quality
wav_00_filtered = wav_00[mask_combined]
times_wav_filtered = timestamps_wav[mask_combined]

print(f"Data points from 13:40h onwards:")
print(f"  Temperature (RTD 7): {len(temp_rtd7_filtered)} points")
print(f"  Wavelength (Sensor 1, Pol 0): {len(wav_00_filtered)} points")

# ========== CREATE ELEGANT DUAL-AXIS PLOT ==========
fig, ax1 = plt.subplots(figsize=(14, 7))

# Temperature on left axis (RTD 7)
color_temp = '#d62728'  # Red
ax1.plot(times_temp_filtered, temp_rtd7_filtered, color=color_temp, linewidth=2.5, 
         marker='o', markersize=6, markerfacecolor=color_temp, 
         markeredgecolor=color_temp, label='RTD 7 Temperature')
ax1.set_xlabel('Time (UTC)', fontsize=14, fontweight='bold')
ax1.set_ylabel('Temperature (K)', fontsize=14, fontweight='bold', color=color_temp)
ax1.tick_params(axis='y', labelcolor=color_temp, labelsize=12)
ax1.tick_params(axis='x', labelsize=12, rotation=45)
plt.setp(ax1.xaxis.get_majorticklabels(), rotation=45, ha='right')

# Wavelength on right axis (Sensor 1, Pol 0)
ax2 = ax1.twinx()
color_wav = '#0066cc'  # Blue
ax2.plot(times_wav_filtered, wav_00_filtered, color=color_wav, linewidth=2.5,
         marker='s', markersize=5, markerfacecolor=color_wav, 
         markeredgecolor=color_wav, label='FBG Sensor 1 (Pol 0)')
ax2.set_ylabel('Wavelength λB (nm)', fontsize=14, fontweight='bold', color=color_wav)
ax2.tick_params(axis='y', labelcolor=color_wav, labelsize=12)

# Title
ax1.set_title('RTD 7 Temperature & FBG Sensor 1 (Pol 0) Evolution\nMarch 10, 2025 | Data from 13:30h to 17:00h', 
             fontsize=16, fontweight='bold', pad=20)

# Grid
ax1.grid(True, alpha=0.3, linestyle='--', linewidth=0.8)
ax1.set_axisbelow(True)

# Combined legend
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left', fontsize=12, 
          framealpha=0.95, edgecolor='black', fancybox=True)

# Statistics box (top right)
temp_mean = temp_rtd7_filtered.mean()
temp_std = temp_rtd7_filtered.std()
wav_mean = wav_00_filtered.mean()
wav_std = wav_00_filtered.std()
stats_text = f'RTD 7:\n  T = {temp_mean:.2f} ± {temp_std:.2f} K\n\nFBG S1-P0:\n  λB = {wav_mean:.4f} ± {wav_std:.4f} nm'
ax1.text(0.98, 0.98, stats_text, transform=ax1.transAxes, 
        fontsize=10, verticalalignment='top', horizontalalignment='right',
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.9, edgecolor='black', linewidth=2))

# Tight layout
fig.tight_layout()
display(fig)
plt.close()

print(f"\n✅ Combined plot generated")
print(f"   RTD 7: {temp_mean:.2f} ± {temp_std:.2f} K")
print(f"   FBG Sensor 1 (Pol 0): {wav_mean:.4f} ± {wav_std:.4f} nm")
# Out:
# Data points from 13:40h onwards:
#   Temperature (RTD 7): 1326 points
#   Wavelength (Sensor 1, Pol 0): 1315 points
# ✅ Combined plot generated
#    RTD 7: 87.51 ± 4.19 K
#    FBG Sensor 1 (Pol 0): 1557.8152 ± 0.0842 nm
